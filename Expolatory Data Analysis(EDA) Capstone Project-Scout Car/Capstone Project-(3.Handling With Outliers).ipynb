# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)
sns.set_style("whitegrid")

pd.set_option("display.float_format", lambda x: "%.3f" % x)

# Set it None to display all rows in the dataframe
# pd.set_option(‘display.max_rows’, None)

# Set it to None to display all columns in the dataframe
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("filled_autoscout.csv")

# %%
df.head(2).T
# Out:
#                                                                         0  \
# body_type                                                          Sedans
# price_€                                                         15770.000
# vat                                                        VAT deductible
# km                                                              56013.000
# hp_kW                                                              66.000
# type                                                                 Used
# previous_owners                                                     2.000
# warranty                                                            0.000
# make                                                                 Audi
# model                                                                  A1
# body_color                                                          Black
# paint_type                                                       Metallic
# upholstery                                                          Cloth
# nr_of_doors                                                         5.000
# nr_of_seats                                                         5.000
# gearing_type                                                    Automatic
# engine_displacement_cc                                           1422.000
# cylinders                                                           3.000
# weight_kg                                                        1220.000
# drive_chain                                                         front
# fuel                                                               Diesel
# co2e_g                                                             99.000
# emission_class                                                     Euro 6
# comfort&convenience     Air conditioning,Armrest,Automatic climate con...
# entertainment&media     Bluetooth,Hands-free equipment,On-board comput...
# extras                     Alloy wheels,Catalytic Converter,Voice Control
# safety&security         ABS,Central door lock,Daytime running lights,D...
# gears                                                               7.000
# country_version                                                   Unknown
# consumption_comb                                                    3.800
# consumption_city                                                    4.300
# consumption_country                                                 3.500
# age                                                                 3.000
#
#                                                                         1
# body_type                                                          Sedans
# price_€                                                         14500.000
# vat                                                      Price negotiable
# km                                                              80000.000
# hp_kW                                                             141.000
# type                                                                 Used
# previous_owners                                                     1.000
# warranty                                                            0.000
# make                                                                 Audi
# model                                                                  A1
# body_color                                                            Red
# paint_type                                                       Metallic
# upholstery                                                          Cloth
# nr_of_doors                                                         3.000
# nr_of_seats                                                         4.000
# gearing_type                                                    Automatic
# engine_displacement_cc                                           1798.000
# cylinders                                                           4.000
# weight_kg                                                        1255.000
# drive_chain                                                         front
# fuel                                                              Benzine
# co2e_g                                                            129.000
# emission_class                                                     Euro 6
# comfort&convenience     Air conditioning,Automatic climate control,Hil...
# entertainment&media     Bluetooth,Hands-free equipment,On-board comput...
# extras                  Alloy wheels,Sport seats,Sport suspension,Voic...
# safety&security         ABS,Central door lock,Central door lock with r...
# gears                                                               7.000
# country_version                                                   Unknown
# consumption_comb                                                    5.600
# consumption_city                                                    7.100
# consumption_country                                                 4.700
# age                                                                 2.000

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %%
def detect_outlier(col):
    print('column name : ',col)
    print("--"*20)
    Q1 = df[col].quantile(0.25)
    print("Q1 : ", Q1)
    Q3 = df[col].quantile(0.75)
    print("Q3 : ", Q3)
    IQR = Q3 - Q1
    print("IQR : ", IQR )
    lower_lim = Q1 - 1.5*IQR
    print("lower limit : ", lower_lim)
    print("mean        : ", round(df[col].mean(), 2))
    upper_lim = Q3 +1.5*IQR
    print("upper limit : ", upper_lim)
    cnt_of_lower = (df[col] < lower_lim).sum()
    print("count of lower values : ", cnt_of_lower)
    cnt_of_upper = (df[col] > upper_lim).sum()
    print("count of upper values : ", cnt_of_upper)
    print(" ")
    print("the smallest 10 values :\n", df[col].sort_values().head(10))
    print(" ")
    print("the biggest 10 values :\n", df[col].sort_values(ascending = False).head(10))
    
    print("\n\n")

# %%
for i in df.select_dtypes(exclude="O").columns:
    detect_outlier(i)
# Out:
# column name :  price_€
# ----------------------------------------
# Q1 :  12850.0
# Q3 :  21900.0
# IQR :  9050.0
# lower limit :  -725.0
# mean        :  18019.9
# upper limit :  35475.0
# count of lower values :  0
# count of upper values :  479
#
# the smallest 10 values :
#  8594      13.000
# 8828     120.000
# 6066     255.000
# 8829     331.000
# 8827    4950.000
# 8825    4990.000
# 8826    5250.000
# 8824    5300.000
# 13770   5445.000
# 8823    5450.000
# Name: price_€, dtype: float64
#
# the biggest 10 values :
#  3648    74600.000
# 15826   68320.000
# 3649    67600.000
# 3587    64900.000
# 15828   64332.000
# 15831   64298.000
# 3595    63900.000
# 15833   63477.000
# 3590    62900.000
# 3594    58990.000
# Name: price_€, dtype: float64
#
#
#
# column name :  km
# ----------------------------------------
# Q1 :  2000.0
# Q3 :  46898.5
# IQR :  44898.5
# lower limit :  -65347.75
# mean        :  31964.85
# upper limit :  114246.25
# count of lower values :  0
# count of upper values :  691
#
# the smallest 10 values :
#  14518   0.000
# 9892    0.000
# 2496    0.000
# 9882    0.000
# 15668   0.000
# 5553    0.000
# 12512   0.000
# 5672    0.000
# 9929    0.000
# 7828    0.000
# Name: km, dtype: float64
#
# the biggest 10 values :
#  9279    317000.000
# 3003    291800.000
# 5712    260000.000
# 6224    248000.000
# 15277   240000.000
# 10804   232000.000
# 6380    231879.000
# 6062    230928.000
# 6399    229500.000
# 10495   222346.000
# Name: km, dtype: float64
#
#
#
# column name :  hp_kW
# ----------------------------------------
# Q1 :  66.0
# Q3 :  101.0
# IQR :  35.0
# lower limit :  13.5
# mean        :  88.37
# upper limit :  153.5
# count of lower values :  22
# count of upper values :  406
#
# the smallest 10 values :
#  6034   1.000
# 7019   1.000
# 7014   1.000
# 9285   1.000
# 6005   1.000
# 9287   1.000
# 9288   1.000
# 7018   1.000
# 9289   1.000
# 9290   1.000
# Name: hp_kW, dtype: float64
#
# the biggest 10 values :
#  3595   294.000
# 3606   294.000
# 3587   294.000
# 3590   294.000
# 3592   294.000
# 3593   294.000
# 3596   294.000
# 3598   294.000
# 3599   294.000
# 3600   294.000
# Name: hp_kW, dtype: float64
#
#
#
# column name :  previous_owners
# ----------------------------------------
# Q1 :  1.0
# Q3 :  1.0
# IQR :  0.0
# lower limit :  1.0
# mean        :  0.95
# upper limit :  1.0
# count of lower values :  1659
# count of upper values :  797
#
# the smallest 10 values :
#  2295    0.000
# 1697    0.000
# 12697   0.000
# 12696   0.000
# 12694   0.000
# 12693   0.000
# 12692   0.000
# 12691   0.000
# 12690   0.000
# 12689   0.000
# Name: previous_owners, dtype: float64
#
# the biggest 10 values :
#  15256   4.000
# 972     4.000
# 14994   3.000
# 9478    3.000
# 10770   3.000
# 13560   3.000
# 1290    3.000
# 11443   3.000
# 13568   3.000
# 15007   3.000
# Name: previous_owners, dtype: float64
#
#
#
# column name :  warranty
# ----------------------------------------
# Q1 :  0.0
# Q3 :  1.0
# IQR :  1.0
# lower limit :  -1.5
# mean        :  0.3
# upper limit :  2.5
# count of lower values :  0
# count of upper values :  0
#
# the smallest 10 values :
#  0      0.000
# 9659   0.000
# 9660   0.000
# 9661   0.000
# 9662   0.000
# 9663   0.000
# 9664   0.000
# 9665   0.000
# 9666   0.000
# 9667   0.000
# Name: warranty, dtype: float64
#
# the biggest 10 values :
#  7959    1.000
# 12349   1.000
# 5174    1.000
# 5173    1.000
# 5171    1.000
# 5169    1.000
# 12343   1.000
# 5166    1.000
# 12346   1.000
# 5161    1.000
# Name: warranty, dtype: float64
#
#
#
# column name :  nr_of_doors
# ----------------------------------------
# Q1 :  4.0
# Q3 :  5.0
# IQR :  1.0
# lower limit :  2.5
# mean        :  4.66
# upper limit :  6.5
# count of lower values :  220
# count of upper values :  1
#
# the smallest 10 values :
#  13782   1.000
# 1811    2.000
# 1228    2.000
# 1229    2.000
# 1230    2.000
# 1231    2.000
# 303     2.000
# 1233    2.000
# 1234    2.000
# 1235    2.000
# Name: nr_of_doors, dtype: float64
#
# the biggest 10 values :
#  15202   7.000
# 0       5.000
# 10023   5.000
# 10012   5.000
# 10013   5.000
# 10014   5.000
# 10015   5.000
# 10016   5.000
# 10017   5.000
# 10018   5.000
# Name: nr_of_doors, dtype: float64
#
#
#
# column name :  nr_of_seats
# ----------------------------------------
# Q1 :  5.0
# Q3 :  5.0
# IQR :  0.0
# lower limit :  5.0
# mean        :  4.95
# upper limit :  5.0
# count of lower values :  1242
# count of upper values :  364
#
# the smallest 10 values :
#  14555   2.000
# 13931   2.000
# 13618   2.000
# 13743   2.000
# 13929   2.000
# 13617   2.000
# 13616   2.000
# 13749   2.000
# 13750   2.000
# 13619   2.000
# Name: nr_of_seats, dtype: float64
#
# the biggest 10 values :
#  15125   7.000
# 15274   7.000
# 15010   7.000
# 15011   7.000
# 15012   7.000
# 15656   7.000
# 15657   7.000
# 15013   7.000
# 15014   7.000
# 15660   7.000
# Name: nr_of_seats, dtype: float64
#
#
#
# column name :  engine_displacement_cc
# ----------------------------------------
# Q1 :  1229.0
# Q3 :  1598.0
# IQR :  369.0
# lower limit :  675.5
# mean        :  1424.82
# upper limit :  2151.5
# count of lower values :  51
# count of upper values :  23
#
# the smallest 10 values :
#  14315   1.000
# 12473   1.000
# 12484   1.000
# 14328   1.000
# 14327   1.000
# 14326   1.000
# 13904   1.000
# 14325   1.000
# 14324   1.000
# 14322   1.000
# Name: engine_displacement_cc, dtype: float64
#
# the biggest 10 values :
#  10932   16000.000
# 7169    15898.000
# 10771    2967.000
# 3609     2480.000
# 3604     2480.000
# 3602     2480.000
# 3601     2480.000
# 3600     2480.000
# 3599     2480.000
# 3598     2480.000
# Name: engine_displacement_cc, dtype: float64
#
#
#
# column name :  cylinders
# ----------------------------------------
# Q1 :  4.0
# Q3 :  4.0
# IQR :  0.0
# lower limit :  4.0
# mean        :  3.79
# upper limit :  4.0
# count of lower values :  3328
# count of upper values :  32
#
# the smallest 10 values :
#  9956    1.000
# 15835   2.000
# 11342   2.000
# 0       3.000
# 2544    3.000
# 2545    3.000
# 2546    3.000
# 2547    3.000
# 2548    3.000
# 2549    3.000
# Name: cylinders, dtype: float64
#
# the biggest 10 values :
#  15151   8.000
# 15197   8.000
# 15186   8.000
# 14989   8.000
# 535     8.000
# 15165   8.000
# 15055   8.000
# 10771   6.000
# 10826   6.000
# 12897   6.000
# Name: cylinders, dtype: float64
#
#
#
# column name :  weight_kg
# ----------------------------------------
# Q1 :  1180.0
# Q3 :  1472.0
# IQR :  292.0
# lower limit :  742.0
# mean        :  1345.4
# upper limit :  1910.0
# count of lower values :  3
# count of upper values :  89
#
# the smallest 10 values :
#  12779     1.000
# 8355      1.000
# 1143    102.000
# 8857    840.000
# 14313   900.000
# 13555   977.000
# 13513   977.000
# 13937   980.000
# 14105   980.000
# 13996   980.000
# Name: weight_kg, dtype: float64
#
# the biggest 10 values :
#  15678   2471.000
# 15185   2471.000
# 15231   2471.000
# 14975   2471.000
# 15280   2471.000
# 10646   2450.000
# 10638   2450.000
# 15133   2410.000
# 15136   2410.000
# 15143   2410.000
# Name: weight_kg, dtype: float64
#
#
#
# column name :  co2e_g
# ----------------------------------------
# Q1 :  104.0
# Q3 :  128.0
# IQR :  24.0
# lower limit :  68.0
# mean        :  122.68
# upper limit :  164.0
# count of lower values :  7
# count of upper values :  247
#
# the smallest 10 values :
#  8110    14.000
# 3617    36.000
# 3615    36.000
# 3612    36.000
# 3356    36.000
# 12547   45.000
# 9798    51.000
# 7857    80.000
# 13668   82.000
# 8912    82.000
# Name: co2e_g, dtype: float64
#
# the biggest 10 values :
#  11888   14457.000
# 12343   13983.000
# 8542    12324.000
# 6578    12087.000
# 6579    12087.000
# 5818    12087.000
# 4089     1060.000
# 4556      990.000
# 535       331.000
# 10513     253.000
# Name: co2e_g, dtype: float64
#
#
#
# column name :  gears
# ----------------------------------------
# Q1 :  5.0
# Q3 :  6.0
# IQR :  1.0
# lower limit :  3.5
# mean        :  5.94
# upper limit :  7.5
# count of lower values :  6
# count of upper values :  300
#
# the smallest 10 values :
#  14375   1.000
# 8921    1.000
# 9812    2.000
# 15817   3.000
# 15845   3.000
# 15846   3.000
# 15823   4.000
# 15822   4.000
# 10287   5.000
# 10288   5.000
# Name: gears, dtype: float64
#
# the biggest 10 values :
#  14495   50.000
# 15830    9.000
# 15827    9.000
# 15876    9.000
# 15814    9.000
# 15813    9.000
# 15812    9.000
# 15869    9.000
# 15824    9.000
# 15829    9.000
# Name: gears, dtype: float64
#
#
#
# column name :  consumption_comb
# ----------------------------------------
# Q1 :  4.1
# Q3 :  5.4
# IQR :  1.3000000000000007
# lower limit :  2.1499999999999986
# mean        :  4.83
# upper limit :  7.350000000000001
# count of lower values :  4
# count of upper values :  130
#
# the smallest 10 values :
#  13678   1.200
# 3615    1.600
# 3617    1.600
# 3612    1.600
# 8872    3.100
# 8904    3.100
# 8874    3.100
# 8566    3.100
# 8912    3.100
# 13680   3.100
# Name: consumption_comb, dtype: float64
#
# the biggest 10 values :
#  535     13.800
# 10513    9.714
# 10771    9.100
# 12529    8.700
# 10817    8.700
# 10819    8.700
# 12054    8.700
# 12530    8.600
# 10789    8.600
# 12422    8.600
# Name: consumption_comb, dtype: float64
#
#
#
# column name :  consumption_city
# ----------------------------------------
# Q1 :  4.7
# Q3 :  6.905263157894736
# IQR :  2.205263157894736
# lower limit :  1.3921052631578963
# mean        :  5.9
# upper limit :  10.21315789473684
# count of lower values :  2
# count of upper values :  34
#
# the smallest 10 values :
#  11553   0.321
# 9756    0.711
# 13008   1.589
# 10755   1.663
# 10758   1.663
# 10759   1.663
# 10764   1.674
# 10870   1.674
# 10866   1.674
# 10860   1.674
# Name: consumption_city, dtype: float64
#
# the biggest 10 values :
#  535     19.900
# 10513   16.100
# 12054   11.500
# 12529   11.500
# 12553   11.500
# 10515   11.500
# 10771   11.300
# 3599    11.300
# 3601    11.300
# 3602    11.300
# Name: consumption_city, dtype: float64
#
#
#
# column name :  consumption_country
# ----------------------------------------
# Q1 :  3.7
# Q3 :  4.6
# IQR :  0.8999999999999995
# lower limit :  2.350000000000001
# mean        :  4.21
# upper limit :  5.949999999999999
# count of lower values :  0
# count of upper values :  171
#
# the smallest 10 values :
#  3290   2.832
# 3268   2.832
# 8930   2.894
# 8851   2.894
# 8948   2.894
# 8827   2.894
# 8932   2.894
# 8933   2.894
# 8934   2.894
# 8935   2.894
# Name: consumption_country, dtype: float64
#
# the biggest 10 values :
#  535     10.300
# 10819   10.110
# 10817   10.110
# 10759    8.600
# 10755    8.600
# 10758    8.600
# 10771    7.800
# 10764    7.800
# 10860    7.800
# 10866    7.800
# Name: consumption_country, dtype: float64
#
#
#
# column name :  age
# ----------------------------------------
# Q1 :  0.0
# Q3 :  2.0
# IQR :  2.0
# lower limit :  -3.0
# mean        :  1.39
# upper limit :  5.0
# count of lower values :  0
# count of upper values :  0
#
# the smallest 10 values :
#  7959   0.000
# 7936   0.000
# 7935   0.000
# 7934   0.000
# 7933   0.000
# 7932   0.000
# 7931   0.000
# 7930   0.000
# 7929   0.000
# 7928   0.000
# Name: age, dtype: float64
#
# the biggest 10 values :
#  0      3.000
# 5938   3.000
# 5955   3.000
# 5954   3.000
# 5953   3.000
# 5952   3.000
# 5950   3.000
# 5949   3.000
# 5947   3.000
# 5940   3.000
# Name: age, dtype: float64

# %% [markdown]
# # **1.price_€**

# %%
detect_outlier("price_€")
# Out:
# column name :  price_€
# ----------------------------------------
# Q1 :  12850.0
# Q3 :  21900.0
# IQR :  9050.0
# lower limit :  -725.0
# mean        :  18019.9
# upper limit :  35475.0
# count of lower values :  0
# count of upper values :  479
#
# the smallest 10 values :
#  8594      13.000
# 8828     120.000
# 6066     255.000
# 8829     331.000
# 8827    4950.000
# 8825    4990.000
# 8826    5250.000
# 8824    5300.000
# 13770   5445.000
# 8823    5450.000
# Name: price_€, dtype: float64
#
# the biggest 10 values :
#  3648    74600.000
# 15826   68320.000
# 3649    67600.000
# 3587    64900.000
# 15828   64332.000
# 15831   64298.000
# 3595    63900.000
# 15833   63477.000
# 3590    62900.000
# 3594    58990.000
# Name: price_€, dtype: float64

# %%
sns.boxplot(x="price_€", data=df);

# %%
# Lower values 0 çıkmasına rağmen ilk 4 değer çok küçük görünüyor. 
# Bu değerlerin outlier olduğunu tespit ettik.
# Upper values 479 çıktı fakat price_€ column kendi içinde değerlendirildiğinde bu fiyatlara outlier demek mantıklı olmayacaktır,
# Araçların özelliklerine göre fiyatlar bu seviyelere kadar artabilir.

# %%
df.iloc[[8594, 8828, 6066, 8829]]
# Out:
#           body_type  price_€             vat       km   hp_kW  type  \
# 8594         Sedans   13.000  VAT deductible  123.000  66.000  Used
# 8828        Compact  120.000  VAT deductible   12.000  66.000   New
# 6066  Station wagon  255.000  VAT deductible 5563.000 100.000  Used
# 8829          Other  331.000  VAT deductible   10.000  66.000   New
#
#       previous_owners  warranty  make  model body_color paint_type upholstery  \
# 8594            1.000     0.000  Opel  Corsa       Gold   Metallic      Cloth
# 8828            0.000     0.000  Opel  Corsa       Grey   Metallic      Cloth
# 6066            1.000     0.000  Opel  Astra       Gold   Metallic      Cloth
# 8829            0.000     0.000  Opel  Corsa      White   Metallic      Cloth
#
#       nr_of_doors  nr_of_seats gearing_type  engine_displacement_cc  \
# 8594        3.000        5.000       Manual                1398.000
# 8828        5.000        5.000       Manual                 999.000
# 6066        5.000        5.000       Manual                1598.000
# 8829        5.000        5.000       Manual                 999.000
#
#       cylinders  weight_kg drive_chain     fuel  co2e_g emission_class  \
# 8594      4.000   1141.000       front  Benzine 128.000   Euro 6d-TEMP
# 8828      3.000   1099.000       front  Benzine 107.000         Euro 6
# 6066      4.000   1403.000       front   Diesel 101.000         Euro 6
# 8829      3.000   1163.000       front  Benzine 128.000   Euro 6d-TEMP
#
#                                     comfort&convenience  \
# 8594  Air conditioning,Cruise control,Electrical sid...
# 8828  Air conditioning,Automatic climate control,Cru...
# 6066  Air conditioning,Cruise control,Electrical sid...
# 8829  Air conditioning,Armrest,Automatic climate con...
#
#                                     entertainment&media  \
# 8594  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 8828              Digital radio,On-board computer,Radio
# 6066  Bluetooth,Hands-free equipment,On-board comput...
# 8829       Hands-free equipment,On-board computer,Radio
#
#                              extras  \
# 8594                   Alloy wheels
# 8828  Alloy wheels,Sport suspension
# 6066                      Roof rack
# 8829     Alloy wheels,Sport package
#
#                                         safety&security  gears  \
# 8594  ABS,Adaptive headlights,Central door lock with...  5.000
# 8828  Central door lock,Daytime running lights,Drive...  6.000
# 6066  ABS,Central door lock with remote control,Dayt...  6.000
# 8829  ABS,Central door lock,Driver-side airbag,Elect...  6.000
#
#      country_version  consumption_comb  consumption_city  consumption_country  \
# 8594         Unknown             5.600             6.800                4.900
# 8828     Netherlands             4.600             5.600                4.100
# 6066         Unknown             3.800             4.500                3.400
# 8829     Netherlands             6.650             8.200                5.700
#
#        age
# 8594 1.000
# 8828 0.000
# 6066 1.000
# 8829 0.000

# %%
# df.loc[df["price_€"] < 400,  ["price_€"]] = np.nan 
# it's the same code below

# %%
df["price_€"] = df["price_€"].apply(lambda x: np.nan if x < 400 else x)

# %%
df["price_€"] = df.groupby(["make", "model", "body_type", "age"])["price_€"].apply(lambda x : x.fillna(round(x.mean(),2)))

# %%
df.iloc[[8594, 8828, 6066, 8829]]
# Out:
#           body_type   price_€             vat       km   hp_kW  type  \
# 8594         Sedans 10853.410  VAT deductible  123.000  66.000  Used
# 8828        Compact 13816.200  VAT deductible   12.000  66.000   New
# 6066  Station wagon 16932.860  VAT deductible 5563.000 100.000  Used
# 8829          Other 12310.360  VAT deductible   10.000  66.000   New
#
#       previous_owners  warranty  make  model body_color paint_type upholstery  \
# 8594            1.000     0.000  Opel  Corsa       Gold   Metallic      Cloth
# 8828            0.000     0.000  Opel  Corsa       Grey   Metallic      Cloth
# 6066            1.000     0.000  Opel  Astra       Gold   Metallic      Cloth
# 8829            0.000     0.000  Opel  Corsa      White   Metallic      Cloth
#
#       nr_of_doors  nr_of_seats gearing_type  engine_displacement_cc  \
# 8594        3.000        5.000       Manual                1398.000
# 8828        5.000        5.000       Manual                 999.000
# 6066        5.000        5.000       Manual                1598.000
# 8829        5.000        5.000       Manual                 999.000
#
#       cylinders  weight_kg drive_chain     fuel  co2e_g emission_class  \
# 8594      4.000   1141.000       front  Benzine 128.000   Euro 6d-TEMP
# 8828      3.000   1099.000       front  Benzine 107.000         Euro 6
# 6066      4.000   1403.000       front   Diesel 101.000         Euro 6
# 8829      3.000   1163.000       front  Benzine 128.000   Euro 6d-TEMP
#
#                                     comfort&convenience  \
# 8594  Air conditioning,Cruise control,Electrical sid...
# 8828  Air conditioning,Automatic climate control,Cru...
# 6066  Air conditioning,Cruise control,Electrical sid...
# 8829  Air conditioning,Armrest,Automatic climate con...
#
#                                     entertainment&media  \
# 8594  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 8828              Digital radio,On-board computer,Radio
# 6066  Bluetooth,Hands-free equipment,On-board comput...
# 8829       Hands-free equipment,On-board computer,Radio
#
#                              extras  \
# 8594                   Alloy wheels
# 8828  Alloy wheels,Sport suspension
# 6066                      Roof rack
# 8829     Alloy wheels,Sport package
#
#                                         safety&security  gears  \
# 8594  ABS,Adaptive headlights,Central door lock with...  5.000
# 8828  Central door lock,Daytime running lights,Drive...  6.000
# 6066  ABS,Central door lock with remote control,Dayt...  6.000
# 8829  ABS,Central door lock,Driver-side airbag,Elect...  6.000
#
#      country_version  consumption_comb  consumption_city  consumption_country  \
# 8594         Unknown             5.600             6.800                4.900
# 8828     Netherlands             4.600             5.600                4.100
# 6066         Unknown             3.800             4.500                3.400
# 8829     Netherlands             6.650             8.200                5.700
#
#        age
# 8594 1.000
# 8828 0.000
# 6066 1.000
# 8829 0.000

# %% [markdown]
# # **2.km**

# %%
detect_outlier("km")
# Out:
# column name :  km
# ----------------------------------------
# Q1 :  2000.0
# Q3 :  46898.5
# IQR :  44898.5
# lower limit :  -65347.75
# mean        :  31964.85
# upper limit :  114246.25
# count of lower values :  0
# count of upper values :  691
#
# the smallest 10 values :
#  14518   0.000
# 9892    0.000
# 2496    0.000
# 9882    0.000
# 15668   0.000
# 5553    0.000
# 12512   0.000
# 5672    0.000
# 9929    0.000
# 7828    0.000
# Name: km, dtype: float64
#
# the biggest 10 values :
#  9279    317000.000
# 3003    291800.000
# 5712    260000.000
# 6224    248000.000
# 15277   240000.000
# 10804   232000.000
# 6380    231879.000
# 6062    230928.000
# 6399    229500.000
# 10495   222346.000
# Name: km, dtype: float64

# %%
# nothing done.

# %% [markdown]
# # **3.hp_kW**

# %%
detect_outlier("hp_kW")
# Out:
# column name :  hp_kW
# ----------------------------------------
# Q1 :  66.0
# Q3 :  101.0
# IQR :  35.0
# lower limit :  13.5
# mean        :  88.37
# upper limit :  153.5
# count of lower values :  22
# count of upper values :  406
#
# the smallest 10 values :
#  6034   1.000
# 7019   1.000
# 7014   1.000
# 9285   1.000
# 6005   1.000
# 9287   1.000
# 9288   1.000
# 7018   1.000
# 9289   1.000
# 9290   1.000
# Name: hp_kW, dtype: float64
#
# the biggest 10 values :
#  3595   294.000
# 3606   294.000
# 3587   294.000
# 3590   294.000
# 3592   294.000
# 3593   294.000
# 3596   294.000
# 3598   294.000
# 3599   294.000
# 3600   294.000
# Name: hp_kW, dtype: float64

# %%
df.loc[df["hp_kW"].sort_values(ascending=True).head(50).index]
# Out:
#            body_type   price_€               vat         km  hp_kW  \
# 6034   Station wagon 11600.000    VAT deductible  76010.000  1.000
# 7019          Sedans 11700.000    VAT deductible  69035.000  1.000
# 7014          Sedans 11700.000    VAT deductible  79993.000  1.000
# 9285          Sedans  8300.000  Price negotiable  58912.000  1.000
# 6005   Station wagon 11600.000    VAT deductible  73860.000  1.000
# 9287          Sedans  8300.000  Price negotiable  53522.000  1.000
# 9288          Sedans  8300.000  Price negotiable  60386.000  1.000
# 7018          Sedans 11700.000    VAT deductible  77272.000  1.000
# 9289          Sedans  8300.000  Price negotiable  59217.000  1.000
# 9290          Sedans  8300.000  Price negotiable  51318.000  1.000
# 9292          Sedans  8300.000  Price negotiable  53390.000  1.000
# 9299          Sedans  8300.000    VAT deductible  47140.000  1.000
# 10610  Station wagon 15300.000    VAT deductible  62800.000  1.000
# 10580  Station wagon 16400.000    VAT deductible  68525.000  1.000
# 10579  Station wagon 16400.000    VAT deductible  78762.000  1.000
# 10468  Station wagon 15300.000    VAT deductible  77125.000  1.000
# 15155         Sedans 23800.000    VAT deductible  56340.000  1.000
# 15156         Sedans 23800.000    VAT deductible  69600.000  1.000
# 6946   Station wagon 11900.000    VAT deductible  70090.000  1.000
# 7016          Sedans 11700.000    VAT deductible  62384.000  1.000
# 13885        Compact  8990.000    VAT deductible   9751.000  4.000
# 3913          Sedans 20440.000    VAT deductible  24000.000  9.000
# 8857         Compact  7650.000    VAT deductible    142.000 40.000
# 13759        Compact  5890.000    VAT deductible 134500.000 40.000
# 8408         Compact 12435.000    VAT deductible  21050.000 44.000
# 10284        Compact 10689.000    VAT deductible     10.000 51.000
# 10285        Compact 10689.000    VAT deductible     10.000 51.000
# 10286        Compact 10689.000    VAT deductible     10.000 51.000
# 10287        Compact 10689.000    VAT deductible     10.000 51.000
# 9145          Sedans  8750.000    VAT deductible  15187.000 51.000
# 10288        Compact 10689.000    VAT deductible      1.000 51.000
# 10347         Sedans 11100.000    VAT deductible     16.987 51.000
# 10346         Sedans 11100.000    VAT deductible    100.649 51.000
# 10345         Sedans 11100.000    VAT deductible    100.649 51.000
# 10283        Compact 10689.000    VAT deductible     10.000 51.000
# 10331        Compact 10288.000    VAT deductible     10.000 51.000
# 9025          Sedans  7650.000    VAT deductible 137058.000 51.000
# 10289        Compact 10689.000    VAT deductible     10.000 51.000
# 10290        Compact 10689.000    VAT deductible     10.000 51.000
# 10342        Compact 10990.000    VAT deductible     10.000 51.000
# 9159          Sedans  8800.000    VAT deductible  35000.000 51.000
# 9158         Compact  8800.000    VAT deductible  25367.000 51.000
# 10291        Compact 10680.000    VAT deductible     16.987 51.000
# 10292        Compact 10141.000    VAT deductible     51.000 51.000
# 10294         Sedans 10100.000    VAT deductible     16.987 51.000
# 9026          Sedans  7650.000    VAT deductible 137058.000 51.000
# 10282        Compact 10689.000    VAT deductible     10.000 51.000
# 10281        Compact 10689.000    VAT deductible     10.000 51.000
# 10280        Compact 10689.000    VAT deductible     10.000 51.000
# 10266        Compact 10690.000    VAT deductible      5.000 51.000
#
#                  type  previous_owners  warranty     make     model  \
# 6034             Used            1.000     0.000     Opel     Astra
# 7019             Used            1.000     0.000     Opel     Astra
# 7014             Used            1.000     0.000     Opel     Astra
# 9285             Used            1.000     0.000     Opel     Corsa
# 6005             Used            1.000     0.000     Opel     Astra
# 9287             Used            1.000     0.000     Opel     Corsa
# 9288             Used            1.000     0.000     Opel     Corsa
# 7018             Used            1.000     0.000     Opel     Astra
# 9289             Used            1.000     0.000     Opel     Corsa
# 9290             Used            1.000     0.000     Opel     Corsa
# 9292             Used            1.000     0.000     Opel     Corsa
# 9299             Used            1.000     0.000     Opel     Corsa
# 10610            Used            1.000     0.000     Opel  Insignia
# 10580            Used            1.000     0.000     Opel  Insignia
# 10579            Used            1.000     0.000     Opel  Insignia
# 10468            Used            1.000     0.000     Opel  Insignia
# 15155            Used            1.000     0.000  Renault    Espace
# 15156            Used            1.000     0.000  Renault    Espace
# 6946             Used            1.000     0.000     Opel     Astra
# 7016             Used            1.000     0.000     Opel     Astra
# 13885            Used            1.000     1.000  Renault      Clio
# 3913             Used            1.000     0.000     Audi        A3
# 8857              New            0.000     1.000     Opel     Corsa
# 13759            Used            1.000     1.000  Renault      Clio
# 8408             Used            1.000     0.000     Opel     Corsa
# 10284  Pre-registered            1.000     0.000     Opel     Corsa
# 10285  Pre-registered            1.000     0.000     Opel     Corsa
# 10286  Pre-registered            1.000     0.000     Opel     Corsa
# 10287  Pre-registered            1.000     0.000     Opel     Corsa
# 9145             Used            1.000     1.000     Opel     Corsa
# 10288  Pre-registered            1.000     0.000     Opel     Corsa
# 10347             New            0.000     1.000     Opel     Corsa
# 10346  Pre-registered            1.000     1.000     Opel     Corsa
# 10345  Pre-registered            1.000     0.000     Opel     Corsa
# 10283  Pre-registered            1.000     0.000     Opel     Corsa
# 10331  Pre-registered            1.000     0.000     Opel     Corsa
# 9025             Used            1.000     0.000     Opel     Corsa
# 10289  Pre-registered            1.000     0.000     Opel     Corsa
# 10290  Pre-registered            1.000     0.000     Opel     Corsa
# 10342  Pre-registered            1.000     0.000     Opel     Corsa
# 9159             Used            1.000     1.000     Opel     Corsa
# 9158             Used            1.000     0.000     Opel     Corsa
# 10291             New            0.000     0.000     Opel     Corsa
# 10292  Pre-registered            1.000     1.000     Opel     Corsa
# 10294             New            0.000     1.000     Opel     Corsa
# 9026             Used            1.000     0.000     Opel     Corsa
# 10282  Pre-registered            1.000     0.000     Opel     Corsa
# 10281  Pre-registered            1.000     0.000     Opel     Corsa
# 10280  Pre-registered            1.000     0.000     Opel     Corsa
# 10266  Pre-registered            1.000     0.000     Opel     Corsa
#
#       body_color paint_type    upholstery  nr_of_doors  nr_of_seats  \
# 6034      Silver   Metallic         Cloth        5.000        5.000
# 7019       Black   Metallic         Other        5.000        5.000
# 7014      Silver   Metallic         Other        5.000        5.000
# 9285       Black   Metallic         Cloth        5.000        5.000
# 6005       Black   Metallic         Cloth        5.000        5.000
# 9287      Silver   Metallic         Cloth        5.000        5.000
# 9288      Silver   Metallic         Cloth        5.000        5.000
# 7018       Black   Metallic         Other        5.000        5.000
# 9289      Silver   Metallic         Cloth        5.000        5.000
# 9290      Silver   Metallic         Cloth        5.000        5.000
# 9292      Silver   Metallic         Cloth        5.000        5.000
# 9299       Black   Metallic         Cloth        5.000        5.000
# 10610     Silver   Metallic         Cloth        5.000        5.000
# 10580     Silver   Metallic         Cloth        5.000        5.000
# 10579     Silver   Metallic         Cloth        5.000        5.000
# 10468      Black   Metallic  Full leather        5.000        5.000
# 15155       Grey   Metallic  Full leather        5.000        5.000
# 15156      Black   Metallic  Full leather        5.000        5.000
# 6946       Black   Metallic         Cloth        5.000        5.000
# 7016       Black   Metallic         Other        5.000        5.000
# 13885       Grey   Metallic         Cloth        5.000        5.000
# 3913       Black   Metallic         Cloth        5.000        5.000
# 8857        Grey   Metallic         Other        3.000        5.000
# 13759      White   Metallic         Cloth        5.000        5.000
# 8408       White   Metallic         Cloth        5.000        5.000
# 10284       Blue   Metallic         Cloth        3.000        5.000
# 10285       Blue   Metallic         Cloth        3.000        5.000
# 10286       Blue   Metallic         Cloth        3.000        5.000
# 10287       Blue   Metallic         Cloth        3.000        5.000
# 9145        Blue   Metallic         Cloth        3.000        5.000
# 10288       Blue   Metallic         Cloth        3.000        5.000
# 10347     Silver   Metallic         Cloth        3.000        5.000
# 10346     Silver   Metallic         Cloth        5.000        5.000
# 10345      White  Uni/basic         Cloth        5.000        5.000
# 10283       Blue   Metallic         Cloth        3.000        5.000
# 10331       Blue   Metallic         Cloth        3.000        5.000
# 9025       White   Metallic         Cloth        5.000        5.000
# 10289       Blue   Metallic         Cloth        3.000        5.000
# 10290       Blue   Metallic         Cloth        3.000        5.000
# 10342      Black   Metallic         Cloth        4.000        4.000
# 9159        Grey   Metallic         Cloth        5.000        5.000
# 9158       Green   Metallic         Cloth        3.000        5.000
# 10291      Black   Metallic         Cloth        3.000        5.000
# 10292        Red   Metallic         Cloth        3.000        5.000
# 10294       Blue   Metallic         Cloth        5.000        5.000
# 9026       White   Metallic         Cloth        5.000        5.000
# 10282       Blue   Metallic         Cloth        3.000        5.000
# 10281       Blue   Metallic         Cloth        3.000        5.000
# 10280       Blue   Metallic         Cloth        3.000        5.000
# 10266       Grey   Metallic         Cloth        3.000        5.000
#
#       gearing_type  engine_displacement_cc  cylinders  weight_kg drive_chain  \
# 6034     Automatic                 998.000      4.000   1393.000       front
# 7019        Manual                1364.000      4.000   1308.000       front
# 7014        Manual                1364.000      4.000   1308.000       front
# 9285        Manual                1229.000      4.000   1163.000       front
# 6005     Automatic                 998.000      4.000   1393.000       front
# 9287        Manual                1229.000      4.000   1163.000       front
# 9288        Manual                1229.000      4.000   1163.000       front
# 7018        Manual                1364.000      4.000   1308.000       front
# 9289        Manual                1229.000      4.000   1163.000       front
# 9290        Manual                1229.000      4.000   1163.000       front
# 9292        Manual                1229.000      4.000   1163.000       front
# 9299        Manual                1229.000      4.000   1163.000       front
# 10610    Automatic                1598.000      4.000   1623.000       front
# 10580    Automatic                1598.000      4.000   1623.000       front
# 10579    Automatic                1598.000      4.000   1623.000       front
# 10468    Automatic                1598.000      4.000   1623.000       front
# 15155    Automatic                1589.000      4.000   1864.500       front
# 15156    Automatic                1589.000      4.000   1864.500       front
# 6946        Manual                1598.000      4.000   1393.000       front
# 7016        Manual                1364.000      4.000   1308.000       front
# 13885       Manual                1598.000      4.000   1090.000       front
# 3913     Automatic                1598.000      4.000   1350.000       front
# 8857        Manual                 973.000      4.000    840.000       front
# 13759       Manual                1461.000      4.000   1090.000       front
# 8408     Automatic                1364.000      4.000   1163.000       front
# 10284       Manual                1229.000      4.000   1163.000       front
# 10285       Manual                1229.000      4.000   1163.000       front
# 10286       Manual                1229.000      4.000   1163.000       front
# 10287       Manual                1229.000      4.000   1163.000       front
# 9145        Manual                1229.000      4.000   1120.000       front
# 10288       Manual                1229.000      4.000   1163.000       front
# 10347       Manual                1229.000      4.000   1088.000       front
# 10346       Manual                1229.000      4.000   1163.000       front
# 10345       Manual                1229.000      4.000   1163.000       front
# 10283       Manual                1229.000      4.000   1163.000       front
# 10331       Manual                1229.000      4.000   1163.000       front
# 9025        Manual                1229.000      4.000   1163.000       front
# 10289       Manual                1229.000      4.000   1163.000       front
# 10290       Manual                1229.000      4.000   1163.000       front
# 10342       Manual                1229.000      4.000   1163.000       front
# 9159        Manual                1229.000      4.000   1163.000       front
# 9158        Manual                1229.000      4.000   1120.000       front
# 10291       Manual                1229.000      4.000   1163.000       front
# 10292       Manual                1229.000      4.000   1163.000       front
# 10294       Manual                1229.000      4.000   1088.000       front
# 9026        Manual                1229.000      4.000   1163.000       front
# 10282       Manual                1229.000      4.000   1163.000       front
# 10281       Manual                1229.000      4.000   1163.000       front
# 10280       Manual                1229.000      4.000   1163.000       front
# 10266       Manual                1229.000      4.000   1163.000       front
#
#           fuel  co2e_g emission_class  \
# 6034   Benzine 125.000         Euro 6
# 7019   Benzine 125.000         Euro 6
# 7014   Benzine 125.000         Euro 6
# 9285   Benzine 128.000         Euro 6
# 6005   Benzine 125.000         Euro 6
# 9287   Benzine 128.000         Euro 6
# 9288   Benzine 128.000         Euro 6
# 7018   Benzine 125.000         Euro 6
# 9289   Benzine 128.000         Euro 6
# 9290   Benzine 128.000         Euro 6
# 9292   Benzine 128.000         Euro 6
# 9299   Benzine 128.000   Euro 6d-TEMP
# 10610   Diesel 135.000         Euro 6
# 10580   Diesel 135.000         Euro 6
# 10579   Diesel 135.000         Euro 6
# 10468   Diesel 135.000         Euro 6
# 15155   Diesel 120.000         Euro 6
# 15156   Diesel 120.000         Euro 6
# 6946    Diesel 101.000         Euro 6
# 7016   Benzine 125.000         Euro 6
# 13885  Benzine 120.000         Euro 6
# 3913    Diesel 105.000         Euro 6
# 8857   Benzine 128.000   Euro 6d-TEMP
# 13759   Diesel  85.000         Euro 6
# 8408   Benzine 128.000         Euro 6
# 10284  Benzine 134.000   Euro 6d-TEMP
# 10285  Benzine 134.000   Euro 6d-TEMP
# 10286  Benzine 134.000   Euro 6d-TEMP
# 10287  Benzine 134.000   Euro 6d-TEMP
# 9145   Benzine 126.000         Euro 6
# 10288  Benzine 134.000   Euro 6d-TEMP
# 10347  Benzine 124.000         Euro 6
# 10346  Benzine 128.000   Euro 6d-TEMP
# 10345  Benzine 124.000   Euro 6d-TEMP
# 10283  Benzine 134.000   Euro 6d-TEMP
# 10331  Benzine 129.000         Euro 6
# 9025    Diesel 101.000         Euro 6
# 10289  Benzine 134.000   Euro 6d-TEMP
# 10290  Benzine 134.000   Euro 6d-TEMP
# 10342  Benzine 132.000   Euro 6d-TEMP
# 9159   Benzine 124.000         Euro 6
# 9158   Benzine 128.000         Euro 6
# 10291  Benzine 129.000   Euro 6d-TEMP
# 10292  Benzine 120.000         Euro 6
# 10294  Benzine 124.000         Euro 6
# 9026    Diesel 101.000         Euro 6
# 10282  Benzine 134.000   Euro 6d-TEMP
# 10281  Benzine 134.000   Euro 6d-TEMP
# 10280  Benzine 134.000   Euro 6d-TEMP
# 10266  Benzine 132.000        Euro 6d
#
#                                      comfort&convenience  \
# 6034   Air conditioning,Electrical side mirrors,Leath...
# 7019   Air conditioning,Automatic climate control,Cru...
# 7014   Air conditioning,Automatic climate control,Cru...
# 9285   Air conditioning,Automatic climate control,Cru...
# 6005   Air conditioning,Electrical side mirrors,Leath...
# 9287   Air conditioning,Automatic climate control,Cru...
# 9288   Air conditioning,Automatic climate control,Cru...
# 7018   Air conditioning,Automatic climate control,Cru...
# 9289   Air conditioning,Automatic climate control,Cru...
# 9290   Air conditioning,Automatic climate control,Cru...
# 9292   Air conditioning,Automatic climate control,Cru...
# 9299   Air conditioning,Automatic climate control,Cru...
# 10610  Air conditioning,Automatic climate control,Cru...
# 10580  Air conditioning,Automatic climate control,Cru...
# 10579  Air conditioning,Automatic climate control,Cru...
# 10468  Air conditioning,Automatic climate control,Cru...
# 15155  Air conditioning,Automatic climate control,Cru...
# 15156  Air conditioning,Automatic climate control,Cru...
# 6946   Air conditioning,Automatic climate control,Cru...
# 7016   Air conditioning,Automatic climate control,Cru...
# 13885                                      Power windows
# 3913   Air conditioning,Automatic climate control,Cru...
# 8857                                    Air conditioning
# 13759                     Air conditioning,Power windows
# 8408   Air conditioning,Cruise control,Electrically h...
# 10284  Air conditioning,Electrical side mirrors,Hill ...
# 10285  Air conditioning,Electrical side mirrors,Hill ...
# 10286  Air conditioning,Electrical side mirrors,Hill ...
# 10287  Air conditioning,Electrical side mirrors,Hill ...
# 9145   Air conditioning,Electrical side mirrors,Power...
# 10288  Air conditioning,Electrical side mirrors,Hill ...
# 10347  Air conditioning,Cruise control,Electrical sid...
# 10346  Air conditioning,Automatic climate control,Pow...
# 10345                     Air conditioning,Power windows
# 10283  Air conditioning,Electrical side mirrors,Hill ...
# 10331  Air conditioning,Electrical side mirrors,Hill ...
# 9025   Air conditioning,Electrical side mirrors,Hill ...
# 10289  Air conditioning,Electrical side mirrors,Hill ...
# 10290  Air conditioning,Electrical side mirrors,Hill ...
# 10342  Air conditioning,Electrical side mirrors,Hill ...
# 9159                      Air conditioning,Power windows
# 9158   Air conditioning,Electrical side mirrors,Hill ...
# 10291         Air conditioning,Hill Holder,Power windows
# 10292  Air conditioning,Electrical side mirrors,Hill ...
# 10294      Air conditioning,Cruise control,Power windows
# 9026   Air conditioning,Electrical side mirrors,Hill ...
# 10282  Air conditioning,Electrical side mirrors,Hill ...
# 10281  Air conditioning,Electrical side mirrors,Hill ...
# 10280  Air conditioning,Electrical side mirrors,Hill ...
# 10266  Air conditioning,Electrical side mirrors,Hill ...
#
#                                      entertainment&media  \
# 6034               Bluetooth,On-board computer,Radio,USB
# 7019                                     CD player,Radio
# 7014                                     CD player,Radio
# 9285     Bluetooth,CD player,On-board computer,Radio,USB
# 6005               Bluetooth,On-board computer,Radio,USB
# 9287     Bluetooth,CD player,On-board computer,Radio,USB
# 9288     Bluetooth,CD player,On-board computer,Radio,USB
# 7018                                     CD player,Radio
# 9289     Bluetooth,CD player,On-board computer,Radio,USB
# 9290     Bluetooth,CD player,On-board computer,Radio,USB
# 9292     Bluetooth,CD player,On-board computer,Radio,USB
# 9299     Bluetooth,CD player,On-board computer,Radio,USB
# 10610    Bluetooth,CD player,On-board computer,Radio,USB
# 10580    Bluetooth,CD player,On-board computer,Radio,USB
# 10579    Bluetooth,CD player,On-board computer,Radio,USB
# 10468    Bluetooth,CD player,On-board computer,Radio,USB
# 15155    Bluetooth,CD player,On-board computer,Radio,USB
# 15156    Bluetooth,CD player,On-board computer,Radio,USB
# 6946     Bluetooth,CD player,On-board computer,Radio,USB
# 7016                                     CD player,Radio
# 13885                                  On-board computer
# 3913   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 8857   Bluetooth,Hands-free equipment,On-board comput...
# 13759  Bluetooth,Hands-free equipment,On-board comput...
# 8408   Bluetooth,CD player,Hands-free equipment,On-bo...
# 10284  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10285  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10286  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10287  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 9145       Bluetooth,CD player,MP3,On-board computer,USB
# 10288  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10347  Bluetooth,CD player,Hands-free equipment,MP3,R...
# 10346                                              Radio
# 10345                                              Radio
# 10283  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10331                                              Radio
# 9025                           Bluetooth,CD player,Radio
# 10289  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10290  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10342    Bluetooth,CD player,On-board computer,Radio,USB
# 9159                                               Radio
# 9158                                  Radio,Sound system
# 10291                            On-board computer,Radio
# 10292                  Bluetooth,On-board computer,Radio
# 10294    Bluetooth,CD player,MP3,On-board computer,Radio
# 9026                           Bluetooth,CD player,Radio
# 10282  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10281  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10280  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10266                            On-board computer,Radio
#
#                                                   extras  \
# 6034          Catalytic Converter,Roof rack,Touch screen
# 7019                                        Alloy wheels
# 7014                                        Alloy wheels
# 9285                                        Alloy wheels
# 6005                                           Roof rack
# 9287                                        Alloy wheels
# 9288                                        Alloy wheels
# 7018                                        Alloy wheels
# 9289                                        Alloy wheels
# 9290                                        Alloy wheels
# 9292                          Alloy wheels,Trailer hitch
# 9299                    Alloy wheels,Catalytic Converter
# 10610            Alloy wheels,Touch screen,Voice Control
# 10580                             Alloy wheels,Roof rack
# 10579                             Alloy wheels,Roof rack
# 10468                         Sport package,Touch screen
# 15155            Alloy wheels,Touch screen,Voice Control
# 15156            Alloy wheels,Touch screen,Voice Control
# 6946                             Roof rack,Trailer hitch
# 7016                                        Alloy wheels
# 13885                         Alloy wheels,Voice Control
# 3913                        Sport seats,Sport suspension
# 8857                                        Alloy wheels
# 13759                                       Touch screen
# 8408                            Alloy wheels,Sport seats
# 10284                         Touch screen,Voice Control
# 10285                         Touch screen,Voice Control
# 10286                         Touch screen,Voice Control
# 10287                         Touch screen,Voice Control
# 9145   Alloy wheels,Sport package,Sport seats,Voice C...
# 10288                         Touch screen,Voice Control
# 10347                                       Touch screen
# 10346                                       Touch screen
# 10345                                       Touch screen
# 10283                         Touch screen,Voice Control
# 10331                                Catalytic Converter
# 9025                    Alloy wheels,Catalytic Converter
# 10289                         Touch screen,Voice Control
# 10290                         Touch screen,Voice Control
# 10342                                Catalytic Converter
# 9159      Alloy wheels,Catalytic Converter,Trailer hitch
# 9158                                 Catalytic Converter
# 10291                         Touch screen,Voice Control
# 10292                                       Alloy wheels
# 10294                         Touch screen,Voice Control
# 9026                    Alloy wheels,Catalytic Converter
# 10282                         Touch screen,Voice Control
# 10281                         Touch screen,Voice Control
# 10280                         Touch screen,Voice Control
# 10266                                Catalytic Converter
#
#                                          safety&security  gears  \
# 6034   Alarm system,Central door lock,Driver-side air...  6.000
# 7019   Driver-side airbag,Electronic stability contro...  6.000
# 7014   Driver-side airbag,Electronic stability contro...  6.000
# 9285   Alarm system,Central door lock,Driver-side air...  5.000
# 6005   Alarm system,Central door lock,Driver-side air...  6.000
# 9287   Alarm system,Central door lock,Driver-side air...  5.000
# 9288   Alarm system,Central door lock,Driver-side air...  5.000
# 7018   Driver-side airbag,Electronic stability contro...  6.000
# 9289   Alarm system,Central door lock,Driver-side air...  5.000
# 9290   Alarm system,Central door lock,Driver-side air...  5.000
# 9292   Alarm system,Central door lock,Driver-side air...  5.000
# 9299   Alarm system,Central door lock,Driver-side air...  5.000
# 10610  Alarm system,Central door lock,Driver-side air...  6.000
# 10580  Alarm system,Central door lock,Driver-side air...  6.000
# 10579  Alarm system,Central door lock,Driver-side air...  6.000
# 10468  Alarm system,Central door lock,Driver-side air...  6.000
# 15155  Alarm system,Central door lock,Driver-side air...  7.000
# 15156  Alarm system,Central door lock,Driver-side air...  7.000
# 6946   Central door lock,Driver-side airbag,Electroni...  6.000
# 7016   Driver-side airbag,Electronic stability contro...  6.000
# 13885  ABS,Driver-side airbag,Immobilizer,Passenger-s...  6.000
# 3913   ABS,Central door lock,Daytime running lights,D...  7.000
# 8857   ABS,Central door lock,Driver-side airbag,Immob...  5.000
# 13759  ABS,Central door lock,Driver-side airbag,Immob...  5.000
# 8408   ABS,Central door lock,Daytime running lights,D...  5.000
# 10284  ABS,Central door lock,Daytime running lights,E...  5.000
# 10285  ABS,Central door lock,Daytime running lights,E...  5.000
# 10286  ABS,Central door lock,Daytime running lights,E...  5.000
# 10287  ABS,Central door lock,Daytime running lights,E...  5.000
# 9145   ABS,Central door lock with remote control,Driv...  5.000
# 10288  ABS,Central door lock,Daytime running lights,E...  5.000
# 10347  ABS,Central door lock,Daytime running lights,D...  5.000
# 10346  ABS,Central door lock,Driver-side airbag,Power...  5.000
# 10345  ABS,Central door lock,Driver-side airbag,Elect...  5.000
# 10283  ABS,Central door lock,Daytime running lights,E...  5.000
# 10331  ABS,Central door lock,Daytime running lights,D...  5.000
# 9025   ABS,Central door lock with remote control,Dayt...  5.000
# 10289  ABS,Central door lock,Daytime running lights,E...  5.000
# 10290  ABS,Central door lock,Daytime running lights,E...  5.000
# 10342  ABS,Central door lock,Daytime running lights,D...  5.000
# 9159   ABS,Central door lock,Driver-side airbag,Elect...  5.000
# 9158   ABS,Central door lock,Central door lock with r...  5.000
# 10291  ABS,Central door lock,Daytime running lights,D...  5.000
# 10292  ABS,Central door lock,Daytime running lights,D...  5.000
# 10294  ABS,Central door lock,Driver-side airbag,Elect...  5.000
# 9026   ABS,Central door lock with remote control,Dayt...  5.000
# 10282  ABS,Central door lock,Daytime running lights,E...  5.000
# 10281  ABS,Central door lock,Daytime running lights,E...  5.000
# 10280  ABS,Central door lock,Daytime running lights,E...  5.000
# 10266  ABS,Central door lock,Daytime running lights,E...  5.000
#
#       country_version  consumption_comb  consumption_city  \
# 6034          Unknown             6.440             8.300
# 7019          Unknown             5.378             7.300
# 7014          Unknown             5.378             7.300
# 9285          Unknown             5.398             6.700
# 6005          Unknown             6.440             8.300
# 9287          Unknown             5.398             6.700
# 9288          Unknown             5.398             6.700
# 7018          Unknown             5.378             7.300
# 9289          Unknown             5.398             6.700
# 9290          Unknown             5.398             6.700
# 9292          Unknown             5.298             6.600
# 9299          Unknown             5.398             6.700
# 10610         Unknown             5.530             7.700
# 10580         Unknown             5.530             7.700
# 10579         Unknown             5.530             7.700
# 10468         Unknown             5.692             7.800
# 15155         Unknown             4.666             5.100
# 15156         Unknown             4.666             5.100
# 6946          Unknown             3.642             4.200
# 7016          Unknown             5.378             7.300
# 13885         Unknown             5.236             6.600
# 3913          Unknown             4.556             5.300
# 8857          Unknown             5.398             6.700
# 13759           Spain             3.300             3.500
# 8408          Germany             5.242             5.800
# 10284         Germany             5.800             7.300
# 10285         Germany             5.800             7.300
# 10286         Germany             5.800             7.300
# 10287         Germany             5.800             7.300
# 9145          Belgium             5.400             6.700
# 10288         Germany             5.800             7.300
# 10347         Unknown             5.300             6.900
# 10346         Unknown             5.300             6.600
# 10345         Unknown             5.300             6.600
# 10283         Germany             5.800             7.300
# 10331         Germany             5.500             7.200
# 9025          Unknown             3.794             4.600
# 10289         Germany             5.800             7.300
# 10290         Germany             5.800             7.300
# 10342           Italy             5.600             7.200
# 9159          Unknown             5.300             6.600
# 9158          Germany             5.400             6.700
# 10291         Germany             5.600             7.300
# 10292         Germany             5.100             6.700
# 10294           Italy             5.300             6.900
# 9026          Unknown             3.794             4.600
# 10282         Germany             5.800             7.300
# 10281         Germany             5.800             7.300
# 10280         Germany             5.800             7.300
# 10266         Germany             5.800             7.300
#
#        consumption_country   age
# 6034                 5.300 2.000
# 7019                 4.200 2.000
# 7014                 4.200 2.000
# 9285                 4.600 2.000
# 6005                 5.300 2.000
# 9287                 4.600 2.000
# 9288                 4.600 2.000
# 7018                 4.200 2.000
# 9289                 4.600 2.000
# 9290                 4.600 2.000
# 9292                 4.500 2.000
# 9299                 4.600 2.000
# 10610                4.200 2.000
# 10580                4.200 2.000
# 10579                4.200 2.000
# 10468                4.400 2.000
# 15155                4.400 2.000
# 15156                4.400 2.000
# 6946                 3.300 2.000
# 7016                 4.200 2.000
# 13885                4.400 2.000
# 3913                 4.100 2.000
# 8857                 4.600 0.000
# 13759                3.100 3.000
# 8408                 4.900 1.000
# 10284                4.900 0.000
# 10285                4.900 0.000
# 10286                4.900 0.000
# 10287                4.900 0.000
# 9145                 4.600 2.000
# 10288                4.900 0.000
# 10347                4.400 0.000
# 10346                4.500 0.000
# 10345                4.500 0.000
# 10283                4.900 0.000
# 10331                4.500 0.000
# 9025                 3.300 3.000
# 10289                4.900 0.000
# 10290                4.900 0.000
# 10342                4.800 0.000
# 9159                 4.500 2.000
# 9158                 4.600 2.000
# 10291                4.700 0.000
# 10292                4.200 0.000
# 10294                4.400 0.000
# 9026                 3.300 3.000
# 10282                4.900 0.000
# 10281                4.900 0.000
# 10280                4.900 0.000
# 10266                4.900 0.000

# %%
df.loc[df["hp_kW"].sort_values(ascending=False).head(50).index]
# Out:
#            body_type   price_€               vat         km   hp_kW  \
# 3595   Station wagon 63900.000    VAT deductible     10.000 294.000
# 3606          Sedans 49900.000    VAT deductible  17234.000 294.000
# 3587          Sedans 64900.000    VAT deductible  35000.000 294.000
# 3590          Sedans 62900.000    VAT deductible    700.000 294.000
# 3592          Sedans 56900.000    VAT deductible   5200.000 294.000
# 3593          Sedans 58500.000    VAT deductible  10000.000 294.000
# 3596          Sedans 57400.000  Price negotiable  63000.000 294.000
# 3598          Sedans 55000.000    VAT deductible  24000.000 294.000
# 3599          Sedans 55000.000    VAT deductible  30000.000 294.000
# 3600          Sedans 53000.000    VAT deductible   4000.000 294.000
# 3601          Sedans 51900.000    VAT deductible  19000.000 294.000
# 3602          Sedans 51900.000    VAT deductible  49000.000 294.000
# 3604          Sedans 50000.000    VAT deductible  25000.000 294.000
# 3605          Sedans 51999.000    VAT deductible  33000.000 294.000
# 3603          Sedans 52000.000    VAT deductible  13963.000 294.000
# 3610          Sedans 45890.000    VAT deductible  18700.000 294.000
# 3648          Sedans 74600.000    VAT deductible  13000.000 294.000
# 3649         Compact 67600.000    VAT deductible  37747.000 294.000
# 3608          Sedans 42500.000  Price negotiable  37333.000 270.000
# 3609          Sedans 41000.000    VAT deductible  30000.000 270.000
# 10513  Station wagon 17990.000    VAT deductible 145000.000 239.000
# 3594          Sedans 58990.000    VAT deductible   7500.000 228.000
# 3597     Convertible 56100.000    VAT deductible   8364.000 228.000
# 11117  Station wagon 11980.000    VAT deductible  89982.000 195.000
# 12529  Station wagon 36180.000    VAT deductible     16.987 191.000
# 12422         Sedans 37599.000    VAT deductible  20000.000 191.000
# 12417         Sedans 37875.000    VAT deductible  27120.000 191.000
# 12553         Sedans 33590.000    VAT deductible   4999.000 191.000
# 12654  Station wagon 30800.000    VAT deductible  11300.000 191.000
# 12530  Station wagon 35380.000    VAT deductible     16.987 191.000
# 10789         Sedans 11600.000    VAT deductible  68000.000 191.000
# 11432         Sedans 19790.000    VAT deductible  42300.000 184.000
# 10507  Station wagon 17999.000  Price negotiable  37550.000 184.000
# 10571  Station wagon 16500.000    VAT deductible  75000.000 184.000
# 10515         Sedans 17990.000    VAT deductible  99850.000 184.000
# 10548  Station wagon 17790.000    VAT deductible  37902.000 184.000
# 15718            Van 36590.000    VAT deductible  11034.000 168.000
# 15903            Van 39990.000    VAT deductible     10.000 168.000
# 15688            Van 38650.000    VAT deductible   1200.000 168.000
# 15767            Van 35990.000    VAT deductible  14328.000 167.000
# 15908            Van 39990.000    VAT deductible     10.000 167.000
# 15747            Van 34975.000    VAT deductible     15.000 165.000
# 15763            Van 35995.000    VAT deductible    500.000 165.000
# 15755  Station wagon 34750.000    VAT deductible   5550.000 165.000
# 15753            Van 34798.000    VAT deductible    435.515 165.000
# 15444            Van 33800.000    VAT deductible     10.000 165.000
# 15734            Van 35475.000    VAT deductible     15.000 165.000
# 15434            Van 31890.000    VAT deductible     16.987 165.000
# 15749            Van 34975.000    VAT deductible     15.000 165.000
# 15745            Van 34950.000    VAT deductible   7800.000 165.000
#
#                  type  previous_owners  warranty     make     model  \
# 3595             Used            1.000     1.000     Audi        A3
# 3606             Used            1.000     0.000     Audi        A3
# 3587             Used            1.000     0.000     Audi        A3
# 3590             Used            1.000     0.000     Audi        A3
# 3592             Used            1.000     0.000     Audi        A3
# 3593             Used            1.000     0.000     Audi        A3
# 3596             Used            1.000     0.000     Audi        A3
# 3598             Used            1.000     0.000     Audi        A3
# 3599             Used            1.000     0.000     Audi        A3
# 3600             Used            1.000     0.000     Audi        A3
# 3601             Used            1.000     0.000     Audi        A3
# 3602             Used            1.000     1.000     Audi        A3
# 3604             Used            1.000     0.000     Audi        A3
# 3605             Used            1.000     0.000     Audi        A3
# 3603             Used            1.000     0.000     Audi        A3
# 3610             Used            1.000     0.000     Audi        A3
# 3648             Used            1.000     0.000     Audi        A3
# 3649             Used            1.000     0.000     Audi        A3
# 3608             Used            1.000     0.000     Audi        A3
# 3609             Used            1.000     0.000     Audi        A3
# 10513            Used            1.000     0.000     Opel  Insignia
# 3594             Used            1.000     0.000     Audi        A3
# 3597             Used            1.000     0.000     Audi        A3
# 11117            Used            1.000     0.000     Opel  Insignia
# 12529             New            0.000     0.000     Opel  Insignia
# 12422   Demonstration            1.000     1.000     Opel  Insignia
# 12417            Used            1.000     1.000     Opel  Insignia
# 12553   Demonstration            1.000     1.000     Opel  Insignia
# 12654            Used            1.000     1.000     Opel  Insignia
# 12530             New            0.000     0.000     Opel  Insignia
# 10789            Used            1.000     0.000     Opel  Insignia
# 11432            Used            1.000     0.000     Opel  Insignia
# 10507            Used            1.000     0.000     Opel  Insignia
# 10571            Used            1.000     0.000     Opel  Insignia
# 10515            Used            1.000     0.000     Opel  Insignia
# 10548            Used            1.000     0.000     Opel  Insignia
# 15718            Used            1.000     1.000  Renault    Espace
# 15903            Used            1.000     1.000  Renault    Espace
# 15688            Used            1.000     1.000  Renault    Espace
# 15767            Used            1.000     1.000  Renault    Espace
# 15908            Used            1.000     1.000  Renault    Espace
# 15747  Pre-registered            1.000     0.000  Renault    Espace
# 15763  Pre-registered            1.000     0.000  Renault    Espace
# 15755   Demonstration            1.000     0.000  Renault    Espace
# 15753  Pre-registered            1.000     0.000  Renault    Espace
# 15444             New            0.000     0.000  Renault    Espace
# 15734  Pre-registered            1.000     0.000  Renault    Espace
# 15434             New            0.000     0.000  Renault    Espace
# 15749  Pre-registered            1.000     0.000  Renault    Espace
# 15745            Used            1.000     0.000  Renault    Espace
#
#       body_color paint_type    upholstery  nr_of_doors  nr_of_seats  \
# 3595       Black   Metallic  Part leather        5.000        5.000
# 3606       Black   Metallic  Part leather        5.000        5.000
# 3587        Grey   Metallic  Full leather        5.000        5.000
# 3590        Grey   Metallic  Part leather        5.000        5.000
# 3592        Grey   Metallic  Full leather        5.000        5.000
# 3593       White   Metallic  Full leather        5.000        5.000
# 3596        Blue   Metallic  Full leather        5.000        5.000
# 3598       Black   Metallic  Full leather        5.000        5.000
# 3599        Grey   Metallic  Full leather        4.000        5.000
# 3600       Black   Metallic  Full leather        4.000        5.000
# 3601       Black   Metallic  Full leather        5.000        5.000
# 3602      Silver   Metallic  Full leather        5.000        5.000
# 3604        Grey   Metallic  Full leather        5.000        5.000
# 3605       White   Metallic  Full leather        5.000        5.000
# 3603        Grey   Metallic  Full leather        5.000        5.000
# 3610       White   Metallic  Part leather        5.000        5.000
# 3648       Black   Metallic  Full leather        4.000        5.000
# 3649       White   Metallic  Full leather        5.000        5.000
# 3608        Grey   Metallic  Part leather        5.000        5.000
# 3609        Blue   Metallic  Part leather        5.000        5.000
# 10513        Red   Metallic  Full leather        4.000        5.000
# 3594        Blue   Metallic  Full leather        5.000        5.000
# 3597        Blue   Metallic  Part leather        2.000        5.000
# 11117      Black   Metallic         Cloth        5.000        5.000
# 12529      White   Metallic         Other        4.000        5.000
# 12422      Black  Uni/basic  Full leather        5.000        5.000
# 12417      White   Metallic  Full leather        5.000        5.000
# 12553      White   Metallic  Part leather        5.000        5.000
# 12654        Red   Metallic  Part leather        5.000        5.000
# 12530      White   Metallic         Other        4.000        5.000
# 10789      White   Metallic         Cloth        5.000        5.000
# 11432       Blue   Metallic  Full leather        4.000        5.000
# 10507       Blue   Metallic         Cloth        5.000        5.000
# 10571      Green   Metallic  Part leather        5.000        5.000
# 10515      Brown   Metallic  Full leather        4.000        5.000
# 10548       Blue   Metallic         Cloth        5.000        5.000
# 15718      Black   Metallic  Full leather        5.000        5.000
# 15903      Black   Metallic  Full leather        5.000        5.000
# 15688      Black   Metallic  Full leather        5.000        5.000
# 15767      Black   Metallic  Full leather        5.000        5.000
# 15908      Black   Metallic  Full leather        5.000        5.000
# 15747      White   Metallic  Full leather        5.000        7.000
# 15763      Brown   Metallic         Cloth        5.000        5.000
# 15755       Grey   Metallic         Cloth        5.000        7.000
# 15753       Grey   Metallic         Cloth        5.000        5.000
# 15444      Black   Metallic  Full leather        4.000        7.000
# 15734      White   Metallic  Full leather        5.000        5.000
# 15434      White   Metallic         Other        5.000        5.000
# 15749      White   Metallic  Full leather        5.000        5.000
# 15745      Black   Metallic  Part leather        4.000        7.000
#
#          gearing_type  engine_displacement_cc  cylinders  weight_kg  \
# 3595   Semi-automatic                2480.000      5.000   1585.000
# 3606   Semi-automatic                2480.000      5.000   1585.000
# 3587   Semi-automatic                2480.000      5.000   1585.000
# 3590   Semi-automatic                2480.000      5.000   1585.000
# 3592   Semi-automatic                2480.000      5.000   1585.000
# 3593   Semi-automatic                2480.000      5.000   1585.000
# 3596   Semi-automatic                2480.000      5.000   1585.000
# 3598   Semi-automatic                2480.000      5.000   1585.000
# 3599   Semi-automatic                2480.000      5.000   1590.000
# 3600   Semi-automatic                2480.000      5.000   1590.000
# 3601   Semi-automatic                2480.000      5.000   1585.000
# 3602   Semi-automatic                2480.000      5.000   1585.000
# 3604   Semi-automatic                2480.000      5.000   1585.000
# 3605   Semi-automatic                2480.000      5.000   1585.000
# 3603   Semi-automatic                2480.000      5.000   1585.000
# 3610   Semi-automatic                2480.000      5.000   1585.000
# 3648   Semi-automatic                2480.000      5.000   1490.000
# 3649   Semi-automatic                2480.000      5.000   1485.000
# 3608   Semi-automatic                2480.000      5.000   1595.000
# 3609   Semi-automatic                2480.000      5.000   1595.000
# 10513       Automatic                1598.000      4.000   1623.000
# 3594   Semi-automatic                1984.000      4.000   1350.000
# 3597   Semi-automatic                1984.000      4.000   1635.000
# 11117          Manual                1956.000      4.000   1623.000
# 12529       Automatic                1998.000      4.000   1623.000
# 12422       Automatic                1998.000      4.000   1440.000
# 12417       Automatic                1998.000      4.000   1649.000
# 12553       Automatic                1998.000      4.000   1503.000
# 12654       Automatic                1998.000      4.000   1487.000
# 12530       Automatic                1998.000      4.000   1623.000
# 10789       Automatic                1998.000      4.000   1503.000
# 11432       Automatic                1998.000      4.000   1503.000
# 10507       Automatic                1998.000      4.000   1733.000
# 10571       Automatic                1998.000      4.000   1733.000
# 10515       Automatic                1998.000      4.000   1503.000
# 10548       Automatic                1998.000      4.000   1623.000
# 15718       Automatic                1798.000      4.000   1685.000
# 15903       Automatic                1798.000      4.000   1685.000
# 15688       Automatic                1798.000      4.000   1685.000
# 15767       Automatic                1798.000      4.000   1685.000
# 15908       Automatic                1798.000      4.000   1685.000
# 15747       Automatic                1798.000      4.000   1685.000
# 15763       Automatic                1798.000      4.000   1685.000
# 15755       Automatic                1798.000      4.000   1685.000
# 15753       Automatic                1798.000      4.000   1880.000
# 15444       Automatic                1798.000      4.000   1685.000
# 15734       Automatic                1798.000      4.000   1685.000
# 15434       Automatic                1798.000      4.000   1685.000
# 15749       Automatic                1798.000      4.000   1685.000
# 15745       Automatic                1798.000      4.000   1685.000
#
#       drive_chain     fuel  co2e_g emission_class  \
# 3595        front  Benzine 189.000         Euro 6
# 3606        front  Benzine 189.000         Euro 6
# 3587        front  Benzine 189.000         Euro 6
# 3590        front  Benzine 194.000   Euro 6d-TEMP
# 3592          4WD  Benzine 189.000         Euro 6
# 3593        front  Benzine 189.000         Euro 6
# 3596          4WD  Benzine 189.000         Euro 6
# 3598        front  Benzine 189.000         Euro 6
# 3599        front  Benzine 188.000         Euro 6
# 3600        front  Benzine 188.000         Euro 6
# 3601        front  Benzine 189.000         Euro 6
# 3602          4WD  Benzine 189.000         Euro 6
# 3604        front  Benzine 189.000         Euro 6
# 3605          4WD  Benzine 189.000         Euro 6
# 3603        front  Benzine 189.000         Euro 6
# 3610        front  Benzine 189.000         Euro 6
# 3648          4WD  Benzine 188.000         Euro 6
# 3649          4WD  Benzine 189.000         Euro 6
# 3608        front  Benzine 189.000         Euro 6
# 3609        front  Benzine 189.000         Euro 6
# 10513         4WD  Benzine 253.000         Euro 6
# 3594          4WD  Benzine 149.000         Euro 6
# 3597          4WD  Benzine 153.000         Euro 6
# 11117       front   Diesel 130.000         Euro 6
# 12529         4WD  Benzine 199.000         Euro 6
# 12422       front  Benzine 197.000         Euro 6
# 12417       front  Benzine 139.000         Euro 6
# 12553         4WD  Benzine 197.000         Euro 6
# 12654         4WD  Benzine 139.000   Euro 6d-TEMP
# 12530         4WD  Benzine 197.000         Euro 6
# 10789       front  Benzine 197.000         Euro 6
# 11432       front  Benzine 184.000         Euro 6
# 10507       front  Benzine 189.000         Euro 6
# 10571       front  Benzine 189.000         Euro 6
# 10515         4WD  Benzine 194.000         Euro 6
# 10548       front  Benzine 190.000         Euro 6
# 15718       front  Benzine 153.000   Euro 6d-TEMP
# 15903       front  Benzine 153.000         Euro 6
# 15688       front  Benzine 153.000         Euro 6
# 15767       front  Benzine 153.000         Euro 6
# 15908       front  Benzine 153.000         Euro 6
# 15747       front  Benzine 168.000   Euro 6d-TEMP
# 15763       front  Benzine 153.000         Euro 6
# 15755       front  Benzine 153.000         Euro 6
# 15753       front  Benzine 153.000         Euro 6
# 15444       front  Benzine 168.000        Euro 6c
# 15734       front  Benzine 168.000   Euro 6d-TEMP
# 15434       front  Benzine 168.000         Euro 6
# 15749       front  Benzine 168.000   Euro 6d-TEMP
# 15745       front  Benzine 153.000         Euro 6
#
#                                      comfort&convenience  \
# 3595   Air conditioning,Armrest,Automatic climate con...
# 3606   Air conditioning,Seat ventilation,Split rear s...
# 3587   Air conditioning,Seat ventilation,Split rear s...
# 3590   Air conditioning,Seat ventilation,Split rear s...
# 3592   Air conditioning,Air suspension,Armrest,Automa...
# 3593   Air conditioning,Seat ventilation,Split rear s...
# 3596   Air conditioning,Air suspension,Armrest,Automa...
# 3598   Air conditioning,Seat ventilation,Split rear s...
# 3599   Air conditioning,Seat ventilation,Split rear s...
# 3600   Air conditioning,Air suspension,Armrest,Automa...
# 3601   Air conditioning,Armrest,Automatic climate con...
# 3602   Air conditioning,Armrest,Automatic climate con...
# 3604   Air conditioning,Automatic climate control,Cru...
# 3605   Air conditioning,Armrest,Automatic climate con...
# 3603   Air conditioning,Air suspension,Automatic clim...
# 3610   Air conditioning,Seat ventilation,Split rear s...
# 3648   Air conditioning,Armrest,Automatic climate con...
# 3649   Air conditioning,Armrest,Automatic climate con...
# 3608   Air conditioning,Seat ventilation,Split rear s...
# 3609   Air conditioning,Armrest,Automatic climate con...
# 10513  Air conditioning,Armrest,Automatic climate con...
# 3594   Air conditioning,Automatic climate control,Cru...
# 3597   Air conditioning,Armrest,Automatic climate con...
# 11117  Air conditioning,Automatic climate control,Cru...
# 12529  Air conditioning,Automatic climate control,Cru...
# 12422  Air conditioning,Automatic climate control,Cru...
# 12417  Air conditioning,Automatic climate control,Cru...
# 12553  Air conditioning,Armrest,Automatic climate con...
# 12654  Air conditioning,Armrest,Automatic climate con...
# 12530  Air conditioning,Automatic climate control,Cru...
# 10789  Air conditioning,Armrest,Automatic climate con...
# 11432  Air conditioning,Automatic climate control,Cru...
# 10507  Air conditioning,Armrest,Automatic climate con...
# 10571  Air conditioning,Armrest,Automatic climate con...
# 10515  Air conditioning,Armrest,Automatic climate con...
# 10548  Air conditioning,Armrest,Automatic climate con...
# 15718  Air conditioning,Automatic climate control,Cru...
# 15903  Air conditioning,Automatic climate control,Cru...
# 15688  Air conditioning,Automatic climate control,Cru...
# 15767  Air conditioning,Automatic climate control,Cru...
# 15908  Air conditioning,Automatic climate control,Cru...
# 15747  Air conditioning,Armrest,Automatic climate con...
# 15763  Air conditioning,Automatic climate control,Cru...
# 15755  Air conditioning,Armrest,Automatic climate con...
# 15753  Air conditioning,Automatic climate control,Cru...
# 15444  Air conditioning,Armrest,Automatic climate con...
# 15734  Air conditioning,Armrest,Automatic climate con...
# 15434  Air conditioning,Automatic climate control,Cru...
# 15749  Air conditioning,Armrest,Automatic climate con...
# 15745  Air conditioning,Armrest,Automatic climate con...
#
#                                      entertainment&media  \
# 3595   Bluetooth,CD player,Digital radio,Hands-free e...
# 3606                                               Radio
# 3587                                               Radio
# 3590                                     Bluetooth,Radio
# 3592   Bluetooth,CD player,Digital radio,Hands-free e...
# 3593                                               Radio
# 3596   Bluetooth,CD player,Hands-free equipment,On-bo...
# 3598                                               Radio
# 3599                                               Radio
# 3600   Bluetooth,CD player,Digital radio,Hands-free e...
# 3601   Bluetooth,Digital radio,Hands-free equipment,M...
# 3602   Bluetooth,Digital radio,Hands-free equipment,M...
# 3604   Bluetooth,CD player,Hands-free equipment,On-bo...
# 3605   Bluetooth,CD player,Digital radio,Hands-free e...
# 3603   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 3610                                               Radio
# 3648                   CD player,On-board computer,Radio
# 3649                   CD player,On-board computer,Radio
# 3608                                           Bluetooth
# 3609           Bluetooth,Digital radio,On-board computer
# 10513  Bluetooth,CD player,Digital radio,Hands-free e...
# 3594   Bluetooth,CD player,Hands-free equipment,On-bo...
# 3597                   CD player,On-board computer,Radio
# 11117  Bluetooth,CD player,Digital radio,Hands-free e...
# 12529                  Bluetooth,On-board computer,Radio
# 12422                        Bluetooth,On-board computer
# 12417                    Bluetooth,MP3,On-board computer
# 12553  Bluetooth,Digital radio,Hands-free equipment,M...
# 12654  Bluetooth,Hands-free equipment,MP3,On-board co...
# 12530              Bluetooth,MP3,On-board computer,Radio
# 10789                    CD player,MP3,On-board computer
# 11432  Bluetooth,Hands-free equipment,On-board comput...
# 10507  Bluetooth,Digital radio,On-board computer,Radi...
# 10571  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10515  Bluetooth,CD player,Digital radio,On-board com...
# 10548  Bluetooth,Digital radio,Hands-free equipment,O...
# 15718  Bluetooth,Hands-free equipment,On-board comput...
# 15903  Bluetooth,Hands-free equipment,On-board comput...
# 15688  Bluetooth,Hands-free equipment,On-board comput...
# 15767  Bluetooth,Hands-free equipment,On-board comput...
# 15908  Bluetooth,Hands-free equipment,On-board comput...
# 15747  Bluetooth,Hands-free equipment,On-board comput...
# 15763                                                USB
# 15755  Bluetooth,Digital radio,Hands-free equipment,O...
# 15753  Bluetooth,Digital radio,Hands-free equipment,M...
# 15444  Bluetooth,Digital radio,Hands-free equipment,O...
# 15734  Bluetooth,Hands-free equipment,On-board comput...
# 15434                                 Radio,Sound system
# 15749  Bluetooth,Hands-free equipment,On-board comput...
# 15745  Bluetooth,CD player,Digital radio,Hands-free e...
#
#                                                   extras  \
# 3595   Alloy wheels,Shift paddles,Ski bag,Sport packa...
# 3606                                        Alloy wheels
# 3587                                        Alloy wheels
# 3590                                        Alloy wheels
# 3592   Alloy wheels,Shift paddles,Sport package,Sport...
# 3593                                        Alloy wheels
# 3596   Alloy wheels,Sport seats,Sport suspension,Tune...
# 3598                                        Alloy wheels
# 3599                                        Alloy wheels
# 3600   Alloy wheels,Catalytic Converter,Shift paddles...
# 3601   Alloy wheels,Catalytic Converter,Shift paddles...
# 3602   Alloy wheels,Shift paddles,Sport package,Sport...
# 3604   Alloy wheels,Shift paddles,Sport package,Sport...
# 3605   Alloy wheels,Catalytic Converter,Shift paddles...
# 3603   Alloy wheels,Sliding door,Sport package,Sport ...
# 3610                                        Alloy wheels
# 3648           Alloy wheels,Sport seats,Sport suspension
# 3649   Alloy wheels,Roof rack,Sport seats,Sport suspe...
# 3608                                        Alloy wheels
# 3609   Alloy wheels,Shift paddles,Sport package,Sport...
# 10513  Alloy wheels,Roof rack,Shift paddles,Sport pac...
# 3594   Alloy wheels,Sport package,Sport seats,Sport s...
# 3597   Alloy wheels,Shift paddles,Sport seats,Sport s...
# 11117                            Roof rack,Trailer hitch
# 12529                 Alloy wheels,Roof rack,Sport seats
# 12422  Alloy wheels,Sport package,Sport seats,Sport s...
# 12417  Alloy wheels,Sport package,Sport seats,Sport s...
# 12553                      Alloy wheels,Sport suspension
# 12654                          Alloy wheels,Touch screen
# 12530                           Alloy wheels,Sport seats
# 10789                     Alloy wheels,Roof rack,Ski bag
# 11432                         Alloy wheels,Shift paddles
# 10507  Alloy wheels,Roof rack,Shift paddles,Sport sus...
# 10571  Alloy wheels,Roof rack,Shift paddles,Sport pac...
# 10515            Alloy wheels,Touch screen,Voice Control
# 10548  Alloy wheels,Catalytic Converter,Roof rack,Shi...
# 15718                                       Alloy wheels
# 15903                                       Alloy wheels
# 15688                                       Alloy wheels
# 15767                                       Alloy wheels
# 15908                                       Alloy wheels
# 15747                                       Alloy wheels
# 15763                          Alloy wheels,Touch screen
# 15755  Alloy wheels,Catalytic Converter,Touch screen,...
# 15753                          Alloy wheels,Touch screen
# 15444            Alloy wheels,Touch screen,Voice Control
# 15734                                       Alloy wheels
# 15434                          Alloy wheels,Touch screen
# 15749                         Alloy wheels,Trailer hitch
# 15745            Alloy wheels,Touch screen,Voice Control
#
#                                          safety&security  gears  \
# 3595   ABS,Adaptive Cruise Control,Adaptive headlight...  7.000
# 3606   Adaptive Cruise Control,Alarm system,Central d...  7.000
# 3587   Adaptive Cruise Control,Alarm system,Central d...  7.000
# 3590   ABS,Adaptive Cruise Control,Alarm system,Centr...  7.000
# 3592   ABS,Adaptive Cruise Control,Adaptive headlight...  7.000
# 3593   Adaptive Cruise Control,Alarm system,Central d...  7.000
# 3596   ABS,Adaptive Cruise Control,Adaptive headlight...  7.000
# 3598   Adaptive Cruise Control,Alarm system,Central d...  7.000
# 3599   Adaptive Cruise Control,Alarm system,Central d...  7.000
# 3600   Adaptive Cruise Control,Adaptive headlights,Al...  7.000
# 3601   ABS,Adaptive Cruise Control,Adaptive headlight...  7.000
# 3602   ABS,Adaptive Cruise Control,Alarm system,Centr...  7.000
# 3604   ABS,Adaptive Cruise Control,Alarm system,Centr...  7.000
# 3605   ABS,Adaptive Cruise Control,Adaptive headlight...  7.000
# 3603   Adaptive Cruise Control,Adaptive headlights,Al...  7.000
# 3610   Adaptive Cruise Control,Alarm system,Central d...  7.000
# 3648   ABS,Alarm system,Central door lock,Driver-side...  7.000
# 3649   ABS,Alarm system,Central door lock,Driver-side...  7.000
# 3608   ABS,Alarm system,Central door lock,Driver-side...  7.000
# 3609   ABS,Adaptive Cruise Control,Alarm system,Centr...  7.000
# 10513  ABS,Adaptive Cruise Control,Blind spot monitor...  6.000
# 3594   ABS,Adaptive Cruise Control,Adaptive headlight...  7.000
# 3597   ABS,Alarm system,Central door lock,Driver-side...  7.000
# 11117  ABS,Blind spot monitor,Central door lock,Dayti...  6.000
# 12529  ABS,Central door lock,Daytime running lights,D...  8.000
# 12422  Driver-side airbag,Electronic stability contro...  8.000
# 12417  ABS,Central door lock,Driver-side airbag,Elect...  8.000
# 12553  ABS,Adaptive Cruise Control,Adaptive headlight...  8.000
# 12654  ABS,Central door lock,Daytime running lights,D...  8.000
# 12530  ABS,Central door lock,Daytime running lights,D...  8.000
# 10789  ABS,Central door lock with remote control,Driv...  6.000
# 11432  ABS,Central door lock,Daytime running lights,D...  6.000
# 10507  ABS,Central door lock with remote control,Dayt...  6.000
# 10571  ABS,Adaptive Cruise Control,Adaptive headlight...  6.000
# 10515  ABS,Adaptive headlights,Central door lock,Dayt...  6.000
# 10548  ABS,Central door lock,Daytime running lights,D...  6.000
# 15718  ABS,Central door lock,Daytime running lights,D...  6.000
# 15903  ABS,Central door lock,Daytime running lights,D...  6.000
# 15688  ABS,Central door lock,Daytime running lights,D...  7.000
# 15767  ABS,Central door lock,Daytime running lights,D...  7.000
# 15908  ABS,Central door lock,Daytime running lights,D...  7.000
# 15747  ABS,Blind spot monitor,Central door lock,Dayti...  7.000
# 15763  ABS,Central door lock,Daytime running lights,D...  7.000
# 15755  ABS,Adaptive Cruise Control,Blind spot monitor...  7.000
# 15753  ABS,Blind spot monitor,Daytime running lights,...  6.000
# 15444  ABS,Blind spot monitor,Central door lock,Dayti...  6.000
# 15734  ABS,Adaptive Cruise Control,Blind spot monitor...  7.000
# 15434  Blind spot monitor,Central door lock,Daytime r...  7.000
# 15749  ABS,Blind spot monitor,Central door lock,Dayti...  7.000
# 15745  ABS,Blind spot monitor,Central door lock,Dayti...  6.000
#
#       country_version  consumption_comb  consumption_city  \
# 3595            Italy             8.300            11.300
# 3606          Unknown             8.300            11.300
# 3587          Unknown             8.300            11.300
# 3590          Unknown             8.300            11.300
# 3592            Italy             8.300            11.300
# 3593          Unknown             8.300            11.300
# 3596          Unknown             8.300            11.300
# 3598          Unknown             8.300            11.300
# 3599          Unknown             8.300            11.300
# 3600            Italy             8.300            11.300
# 3601          Unknown             8.300            11.300
# 3602            Italy             8.300            11.300
# 3604          Unknown             8.300            11.300
# 3605            Italy             8.300            11.300
# 3603          Unknown             8.300            11.300
# 3610            Italy             8.300            11.300
# 3648      Netherlands             8.300            11.300
# 3649      Netherlands             8.300            11.300
# 3608          Unknown             8.100            11.200
# 3609          Unknown             8.100            11.200
# 10513         Germany             9.714            16.100
# 3594          Unknown             6.500             6.200
# 3597      Netherlands             7.100            11.300
# 11117         Unknown             4.900             6.700
# 12529          Poland             8.700            11.500
# 12422         Unknown             8.600             7.300
# 12417         Unknown             5.436             6.800
# 12553         Unknown             8.600            11.500
# 12654         Unknown             6.212             7.700
# 12530          Poland             8.600            11.200
# 10789         Unknown             8.600            11.200
# 11432         Germany             7.800            10.800
# 10507         Unknown             6.832             7.700
# 10571         Unknown             6.414             6.600
# 10515         Germany             8.300            11.500
# 10548         Germany             6.200             7.832
# 15718         Unknown             7.364             9.100
# 15903         Unknown             6.840             8.700
# 15688         Unknown             7.364             9.100
# 15767         Unknown             6.840             8.700
# 15908         Unknown             6.840             8.700
# 15747         Austria             7.400             9.200
# 15763         Germany             6.800             8.700
# 15755         Unknown             6.800             8.700
# 15753         Germany             6.800             8.700
# 15444  European Union             7.400             9.200
# 15734         Austria             7.400             9.200
# 15434         Germany             7.400             9.600
# 15749         Austria             7.400             9.200
# 15745         Germany             6.800             8.700
#
#        consumption_country   age
# 3595                 6.600 0.000
# 3606                 6.600 1.000
# 3587                 6.600 1.000
# 3590                 6.600 0.000
# 3592                 6.600 1.000
# 3593                 6.600 1.000
# 3596                 6.600 1.000
# 3598                 6.600 2.000
# 3599                 6.500 1.000
# 3600                 6.500 1.000
# 3601                 6.600 2.000
# 3602                 6.600 1.000
# 3604                 6.600 1.000
# 3605                 6.600 2.000
# 3603                 6.600 1.000
# 3610                 6.600 1.000
# 3648                 6.500 1.000
# 3649                 6.600 2.000
# 3608                 6.300 3.000
# 3609                 6.300 3.000
# 10513                5.800 3.000
# 3594                 4.200 1.000
# 3597                 6.600 1.000
# 11117                3.800 2.000
# 12529                7.100 0.000
# 12422                4.800 0.000
# 12417                4.600 0.000
# 12553                6.823 0.000
# 12654                5.300 0.000
# 12530                7.100 0.000
# 10789                7.006 2.000
# 11432                6.100 2.000
# 10507                6.300 2.000
# 10571                6.300 2.000
# 10515                6.400 3.000
# 10548                5.200 2.000
# 15718                6.300 0.000
# 15903                5.700 0.000
# 15688                6.300 0.000
# 15767                5.700 1.000
# 15908                5.700 0.000
# 15747                6.300 0.000
# 15763                5.700 1.000
# 15755                5.700 1.000
# 15753                5.700 1.000
# 15444                6.300 0.000
# 15734                6.300 0.000
# 15434                6.052 0.000
# 15749                6.300 0.000
# 15745                5.700 1.000

# %%
df.groupby(["make", "model", "body_type"])["hp_kW"].mean()
# Out:
# make     model     body_type
# Audi     A1        Compact          77.078
#                    Coupe            77.500
#                    Other            80.385
#                    Sedans           76.322
#                    Station wagon    75.143
#                    Van             147.000
#          A2        Off-Road         85.000
#          A3        Compact          89.945
#                    Convertible     124.250
#                    Coupe            82.000
#                    Other            88.188
#                    Sedans           90.077
#                    Station wagon    90.681
# Opel     Astra     Compact          87.849
#                    Coupe           106.500
#                    Off-Road        110.000
#                    Other            86.403
#                    Sedans           90.335
#                    Station wagon    95.689
#          Corsa     Compact          61.700
#                    Coupe            59.462
#                    Off-Road         68.667
#                    Other            65.678
#                    Sedans           57.728
#                    Transporter      54.429
#                    Van              51.000
#          Insignia  Compact         119.852
#                    Coupe            81.000
#                    Off-Road        132.000
#                    Other           103.812
#                    Sedans          110.916
#                    Station wagon   116.402
#                    Van             121.000
# Renault  Clio      Compact          71.659
#                    Coupe           147.000
#                    Off-Road         71.000
#                    Other            68.804
#                    Sedans           73.767
#                    Station wagon    64.487
#                    Transporter      57.379
#                    Van              55.000
#          Duster    Off-Road         77.118
#          Espace    Compact         135.667
#                    Coupe           141.500
#                    Off-Road        118.000
#                    Other           127.375
#                    Sedans          114.762
#                    Station wagon   130.527
#                    Transporter     116.712
#                    Van             131.214
# Name: hp_kW, dtype: float64

# %%
df[df["hp_kW"] < 33.0][["make", "model"]].value_counts()
# Out:
# make     model
# Opel     Astra       7
#          Corsa       7
#          Insignia    4
# Renault  Espace      2
# Audi     A3          1
# Renault  Clio        1
# dtype: int64

# %%
df[df["hp_kW"] > 195][["make", "model"]].value_counts()
# Out:
# make  model
# Audi  A3          22
# Opel  Insignia     1
# dtype: int64

# %%
def detect_values(col, col2):
    my_list = df[col].unique()
    for i in my_list:
        a = df[df[col] == i][col2].max()
        b = df[df[col] == i][col2].min()
        c = df[df[col] == i][col2].mean()
        print(f"{i} max : {a}   min : {b}   mean : {c}")

# %%
detect_values("make", "hp_kW")
# Out:
# Audi max : 294.0   min : 9.0   mean : 83.99929971988796
# Opel max : 239.0   min : 1.0   mean : 90.53247991284216
# Renault max : 168.0   min : 1.0   mean : 91.55586592178771

# %%
df["hp_kW"] = df["hp_kW"].apply(lambda x: np.nan if x < 33 else x)

# %%
df.groupby(["make", "model", "drive_chain", "engine_displacement_cc"])["hp_kW"].apply(lambda x : x.fillna(x.median() if x.median() > 1 else df["hp_kW"].median())).value_counts(dropna=False)
# Out:
# 85.000     2546
# 66.000     2124
# 81.000     1405
# 100.000    1313
# 110.000    1112
#            ...
# 44.000        1
# 75.000        1
# 123.000       1
# 239.000       1
# 137.000       1
# Name: hp_kW, Length: 78, dtype: int64

# %%
df["hp_kW"] = df.groupby(["make", "model", "drive_chain", "engine_displacement_cc"])["hp_kW"].apply(lambda x : x.fillna(x.median() if x.median() > 1 else df["hp_kW"].median()))

# %% [markdown]
# # **4.previous_owners**

# %%
detect_outlier("previous_owners")
# Out:
# column name :  previous_owners
# ----------------------------------------
# Q1 :  1.0
# Q3 :  1.0
# IQR :  0.0
# lower limit :  1.0
# mean        :  0.95
# upper limit :  1.0
# count of lower values :  1659
# count of upper values :  797
#
# the smallest 10 values :
#  2295    0.000
# 1697    0.000
# 12697   0.000
# 12696   0.000
# 12694   0.000
# 12693   0.000
# 12692   0.000
# 12691   0.000
# 12690   0.000
# 12689   0.000
# Name: previous_owners, dtype: float64
#
# the biggest 10 values :
#  15256   4.000
# 972     4.000
# 14994   3.000
# 9478    3.000
# 10770   3.000
# 13560   3.000
# 1290    3.000
# 11443   3.000
# 13568   3.000
# 15007   3.000
# Name: previous_owners, dtype: float64

# %%
sns.boxplot(x=df.previous_owners);

# %%
# nothing done.

# %% [markdown]
# # **5.warranty**

# %%
detect_outlier("warranty")
# Out:
# column name :  warranty
# ----------------------------------------
# Q1 :  0.0
# Q3 :  1.0
# IQR :  1.0
# lower limit :  -1.5
# mean        :  0.3
# upper limit :  2.5
# count of lower values :  0
# count of upper values :  0
#
# the smallest 10 values :
#  0      0.000
# 9659   0.000
# 9660   0.000
# 9661   0.000
# 9662   0.000
# 9663   0.000
# 9664   0.000
# 9665   0.000
# 9666   0.000
# 9667   0.000
# Name: warranty, dtype: float64
#
# the biggest 10 values :
#  7959    1.000
# 12349   1.000
# 5174    1.000
# 5173    1.000
# 5171    1.000
# 5169    1.000
# 12343   1.000
# 5166    1.000
# 12346   1.000
# 5161    1.000
# Name: warranty, dtype: float64

# %%
# garantisi olanlar 1 olmayanlar 0 atanacak daha sonra.

# %% [markdown]
# # **6.nr_of_doors**

# %%
detect_outlier("nr_of_doors")
# Out:
# column name :  nr_of_doors
# ----------------------------------------
# Q1 :  4.0
# Q3 :  5.0
# IQR :  1.0
# lower limit :  2.5
# mean        :  4.66
# upper limit :  6.5
# count of lower values :  220
# count of upper values :  1
#
# the smallest 10 values :
#  13782   1.000
# 1811    2.000
# 1228    2.000
# 1229    2.000
# 1230    2.000
# 1231    2.000
# 303     2.000
# 1233    2.000
# 1234    2.000
# 1235    2.000
# Name: nr_of_doors, dtype: float64
#
# the biggest 10 values :
#  15202   7.000
# 0       5.000
# 10023   5.000
# 10012   5.000
# 10013   5.000
# 10014   5.000
# 10015   5.000
# 10016   5.000
# 10017   5.000
# 10018   5.000
# Name: nr_of_doors, dtype: float64

# %%
df[df["nr_of_doors"] == 2][["make", "model", "body_type"]].value_counts()
# Out:
# make  model  body_type
# Opel  Corsa  Compact          88
# Audi  A1     Compact          69
#              Sedans           29
#       A3     Sedans           17
#              Convertible       7
# Opel  Corsa  Sedans            4
# Audi  A3     Other             2
#       A1     Coupe             1
#       A3     Station wagon     1
# Opel  Corsa  Other             1
# dtype: int64

# %%
df.loc[(df.nr_of_doors == 1) | (df.nr_of_doors == 7), "nr_of_doors"] = 5

# %% [markdown]
# # **7.nr_of_seats**

# %%
detect_outlier("nr_of_seats")
# Out:
# column name :  nr_of_seats
# ----------------------------------------
# Q1 :  5.0
# Q3 :  5.0
# IQR :  0.0
# lower limit :  5.0
# mean        :  4.95
# upper limit :  5.0
# count of lower values :  1242
# count of upper values :  364
#
# the smallest 10 values :
#  14555   2.000
# 13931   2.000
# 13618   2.000
# 13743   2.000
# 13929   2.000
# 13617   2.000
# 13616   2.000
# 13749   2.000
# 13750   2.000
# 13619   2.000
# Name: nr_of_seats, dtype: float64
#
# the biggest 10 values :
#  15125   7.000
# 15274   7.000
# 15010   7.000
# 15011   7.000
# 15012   7.000
# 15656   7.000
# 15657   7.000
# 15013   7.000
# 15014   7.000
# 15660   7.000
# Name: nr_of_seats, dtype: float64

# %%
df[df["nr_of_seats"] == 7][["make", "model", "body_type"]].value_counts()
# Out:
# make     model   body_type
# Renault  Espace  Van              315
#                  Station wagon     19
#                  Transporter       16
#                  Sedans             4
#                  Off-Road           3
#                  Other              3
#                  Compact            2
# dtype: int64

# %%
df[df["nr_of_seats"] == 2][["make", "model", "body_type"]].value_counts()
# Out:
# make     model     body_type
# Renault  Clio      Sedans           71
#                    Transporter      26
#                    Compact           8
# Opel     Corsa     Transporter       4
# Renault  Clio      Other             4
# Opel     Corsa     Coupe             1
#          Insignia  Station wagon     1
# Renault  Clio      Van               1
# dtype: int64

# %%
# nothing done.

# %% [markdown]
# # **8.engine_displacement_cc**

# %%
detect_outlier("engine_displacement_cc")
# Out:
# column name :  engine_displacement_cc
# ----------------------------------------
# Q1 :  1229.0
# Q3 :  1598.0
# IQR :  369.0
# lower limit :  675.5
# mean        :  1424.82
# upper limit :  2151.5
# count of lower values :  51
# count of upper values :  23
#
# the smallest 10 values :
#  14315   1.000
# 12473   1.000
# 12484   1.000
# 14328   1.000
# 14327   1.000
# 14326   1.000
# 13904   1.000
# 14325   1.000
# 14324   1.000
# 14322   1.000
# Name: engine_displacement_cc, dtype: float64
#
# the biggest 10 values :
#  10932   16000.000
# 7169    15898.000
# 10771    2967.000
# 3609     2480.000
# 3604     2480.000
# 3602     2480.000
# 3601     2480.000
# 3600     2480.000
# 3599     2480.000
# 3598     2480.000
# Name: engine_displacement_cc, dtype: float64

# %%
df.loc[df["engine_displacement_cc"] > 3000.0, "engine_displacement_cc"] = 1600.0

# %%
df.iloc[[10932, 7169]]
# Out:
#            body_type   price_€               vat        km   hp_kW  \
# 10932  Station wagon 14300.000  Price negotiable 76500.000  88.000
# 7169   Station wagon 18490.000    VAT deductible 22327.000 100.000
#
#                  type  previous_owners  warranty  make     model body_color  \
# 10932            Used            1.000     0.000  Opel  Insignia       Grey
# 7169   Employee's car            1.000     0.000  Opel     Astra      Green
#
#       paint_type    upholstery  nr_of_doors  nr_of_seats gearing_type  \
# 10932   Metallic  Full leather        5.000        5.000       Manual
# 7169    Metallic         Cloth        5.000        5.000    Automatic
#
#        engine_displacement_cc  cylinders  weight_kg drive_chain     fuel  \
# 10932                1600.000      4.000   1623.000       front   Diesel
# 7169                 1600.000      4.000   1393.000       front  Benzine
#
#        co2e_g emission_class  \
# 10932 135.000         Euro 6
# 7169  119.000         Euro 6
#
#                                      comfort&convenience  \
# 10932  Air conditioning,Automatic climate control,Cru...
# 7169   Air conditioning,Armrest,Automatic climate con...
#
#                                      entertainment&media  \
# 10932  Bluetooth,Hands-free equipment,MP3,On-board co...
# 7169   Bluetooth,Hands-free equipment,MP3,On-board co...
#
#                                         extras  \
# 10932  Alloy wheels,Touch screen,Voice Control
# 7169   Alloy wheels,Touch screen,Voice Control
#
#                                          safety&security  gears  \
# 10932  ABS,Central door lock,Daytime running lights,D...  6.000
# 7169   ABS,Central door lock,Daytime running lights,D...  6.000
#
#       country_version  consumption_comb  consumption_city  \
# 10932         Unknown             4.500             5.700
# 7169          Unknown             4.500             5.700
#
#        consumption_country   age
# 10932                3.765 3.000
# 7169                 3.800 1.000

# %%
df.iloc[df["engine_displacement_cc"].sort_values().head(60).index]
# Out:
#            body_type   price_€             vat        km   hp_kW  \
# 14315         Sedans  9999.000  VAT deductible  8031.000  54.000
# 12473  Station wagon 34490.000  VAT deductible  3373.868 100.000
# 12484         Sedans 33990.000  VAT deductible    10.000 100.000
# 14328         Sedans  9999.000  VAT deductible 17364.000  54.000
# 14327         Sedans  9999.000  VAT deductible 21543.000  54.000
# 14326         Sedans  9999.000  VAT deductible 14066.000  54.000
# 13904         Sedans  9490.000  VAT deductible 26000.000  54.000
# 14325         Sedans  9999.000  VAT deductible 14532.000  54.000
# 14324         Sedans  9999.000  VAT deductible 30000.000  54.000
# 14322         Sedans  9999.000  VAT deductible 15678.000  54.000
# 14321         Sedans  9999.000  VAT deductible 14039.000  54.000
# 14320         Sedans  9999.000  VAT deductible 15674.000  54.000
# 14319         Sedans  9999.000  VAT deductible 11004.000  54.000
# 12499  Station wagon 36990.000  VAT deductible  3373.868 100.000
# 12501  Station wagon 36990.000  VAT deductible    70.000 100.000
# 12554  Station wagon 33590.000  VAT deductible  1574.000 121.000
# 12604  Station wagon 28990.000  VAT deductible  2254.000 100.000
# 14314         Sedans  9999.000  VAT deductible 11314.000  54.000
# 12768  Station wagon 39190.000  VAT deductible    16.987 100.000
# 12769        Compact 38990.000  VAT deductible  1852.000 147.000
# 12781  Station wagon 36500.000  VAT deductible  3373.868 147.000
# 12783        Compact 36490.000  VAT deductible  3291.000 147.000
# 12786  Station wagon 36780.000  VAT deductible    70.000 100.000
# 12790  Station wagon 35990.000  VAT deductible  2348.000 100.000
# 12467  Station wagon 37490.000  VAT deductible  3373.868 100.000
# 12796         Sedans 35990.000  VAT deductible   136.000 147.000
# 12800  Station wagon 33790.000  VAT deductible  6446.000 125.000
# 12815  Station wagon 32990.000  VAT deductible     6.000 100.000
# 12823  Station wagon 28500.000  VAT deductible  3373.868 121.000
# 12835         Sedans 34925.000  VAT deductible  4631.000 147.000
# 12848  Station wagon 33990.000  VAT deductible  1798.000 100.000
# 12849  Station wagon 33990.000  VAT deductible     8.000 100.000
# 12798  Station wagon 33990.000  VAT deductible  3582.000 100.000
# 12750         Sedans 41490.000  VAT deductible    10.000 147.000
# 12670  Station wagon 29990.000  VAT deductible  3373.868 100.000
# 14284         Sedans  9999.000  VAT deductible 18008.000  54.000
# 10559  Station wagon 16950.000  VAT deductible 84700.000 125.000
# 14198         Sedans  9680.000  VAT deductible 44235.000  66.000
# 13912         Sedans  9400.000  VAT deductible 17000.000  54.000
# 10194        Compact 10940.000  VAT deductible    12.000  51.000
# 7811          Sedans 23940.000  VAT deductible    12.000 110.000
# 7810          Sedans 23940.000  VAT deductible    12.000 110.000
# 7809          Sedans 23940.000  VAT deductible    12.000 110.000
# 7812          Sedans 23940.000  VAT deductible    12.000 110.000
# 8128   Station wagon 18830.000  VAT deductible    10.000  92.000
# 15574            Van 31900.000  VAT deductible     1.000 118.000
# 15576            Van 31900.000  VAT deductible     1.000 118.000
# 15577            Van 31900.000  VAT deductible     1.000 118.000
# 15578            Van 31900.000  VAT deductible     1.000 118.000
# 15579            Van 31900.000  VAT deductible     1.000 118.000
# 15575            Van 31900.000  VAT deductible     1.000 118.000
# 13653         Sedans  6950.000  VAT deductible  4473.934  66.000
# 14668         Sedans 11410.000  VAT deductible   100.649  56.000
# 14667         Sedans 10990.000  VAT deductible    50.000  56.000
# 14666         Sedans 11150.000  VAT deductible    20.000  56.000
# 14665         Sedans 11410.000  VAT deductible   100.649  56.000
# 14620         Sedans 10200.000  VAT deductible 13665.000  66.000
# 14663        Compact 10880.000  VAT deductible   150.000  56.000
# 14619        Compact 10200.000  VAT deductible   421.000  56.000
# 14661         Sedans 10880.000  VAT deductible    50.000  56.000
#
#                  type  previous_owners  warranty     make     model  \
# 14315            Used            1.000     0.000  Renault      Clio
# 12473   Demonstration            1.000     0.000     Opel  Insignia
# 12484   Demonstration            1.000     0.000     Opel  Insignia
# 14328            Used            1.000     0.000  Renault      Clio
# 14327            Used            1.000     0.000  Renault      Clio
# 14326            Used            1.000     0.000  Renault      Clio
# 13904            Used            1.000     0.000  Renault      Clio
# 14325            Used            1.000     0.000  Renault      Clio
# 14324            Used            1.000     0.000  Renault      Clio
# 14322            Used            1.000     0.000  Renault      Clio
# 14321            Used            1.000     0.000  Renault      Clio
# 14320            Used            1.000     0.000  Renault      Clio
# 14319            Used            1.000     0.000  Renault      Clio
# 12499   Demonstration            1.000     0.000     Opel  Insignia
# 12501   Demonstration            1.000     0.000     Opel  Insignia
# 12554   Demonstration            1.000     0.000     Opel  Insignia
# 12604   Demonstration            1.000     0.000     Opel  Insignia
# 14314            Used            1.000     0.000  Renault      Clio
# 12768             New            0.000     0.000     Opel  Insignia
# 12769   Demonstration            1.000     0.000     Opel  Insignia
# 12781   Demonstration            1.000     0.000     Opel  Insignia
# 12783   Demonstration            1.000     0.000     Opel  Insignia
# 12786   Demonstration            1.000     0.000     Opel  Insignia
# 12790   Demonstration            1.000     0.000     Opel  Insignia
# 12467   Demonstration            1.000     0.000     Opel  Insignia
# 12796   Demonstration            1.000     0.000     Opel  Insignia
# 12800   Demonstration            1.000     0.000     Opel  Insignia
# 12815   Demonstration            1.000     0.000     Opel  Insignia
# 12823   Demonstration            1.000     0.000     Opel  Insignia
# 12835   Demonstration            1.000     0.000     Opel  Insignia
# 12848   Demonstration            1.000     0.000     Opel  Insignia
# 12849   Demonstration            1.000     0.000     Opel  Insignia
# 12798   Demonstration            1.000     0.000     Opel  Insignia
# 12750             New            0.000     0.000     Opel  Insignia
# 12670   Demonstration            1.000     0.000     Opel  Insignia
# 14284            Used            1.000     0.000  Renault      Clio
# 10559            Used            1.000     0.000     Opel  Insignia
# 14198            Used            1.000     0.000  Renault      Clio
# 13912            Used            1.000     0.000  Renault      Clio
# 10194  Pre-registered            1.000     0.000     Opel     Corsa
# 7811   Pre-registered            1.000     0.000     Opel     Astra
# 7810   Pre-registered            1.000     0.000     Opel     Astra
# 7809   Pre-registered            1.000     0.000     Opel     Astra
# 7812   Pre-registered            1.000     0.000     Opel     Astra
# 8128    Demonstration            1.000     0.000     Opel     Astra
# 15574  Pre-registered            1.000     0.000  Renault    Espace
# 15576  Pre-registered            1.000     0.000  Renault    Espace
# 15577  Pre-registered            1.000     0.000  Renault    Espace
# 15578  Pre-registered            1.000     0.000  Renault    Espace
# 15579  Pre-registered            1.000     0.000  Renault    Espace
# 15575  Pre-registered            1.000     0.000  Renault    Espace
# 13653  Employee's car            1.000     0.000  Renault      Clio
# 14668  Pre-registered            1.000     0.000  Renault      Clio
# 14667   Demonstration            1.000     1.000  Renault      Clio
# 14666            Used            1.000     1.000  Renault      Clio
# 14665  Pre-registered            1.000     0.000  Renault      Clio
# 14620            Used            1.000     0.000  Renault      Clio
# 14663            Used            1.000     0.000  Renault      Clio
# 14619  Pre-registered            1.000     0.000  Renault      Clio
# 14661            Used            1.000     0.000  Renault      Clio
#
#       body_color paint_type    upholstery  nr_of_doors  nr_of_seats  \
# 14315      White   Metallic         Cloth        5.000        5.000
# 12473     Silver   Metallic  Part leather        5.000        5.000
# 12484      Black   Metallic  Part leather        5.000        5.000
# 14328      White   Metallic         Cloth        5.000        5.000
# 14327      White   Metallic         Cloth        5.000        5.000
# 14326      White   Metallic         Cloth        5.000        5.000
# 13904      White   Metallic         Cloth        5.000        5.000
# 14325      White   Metallic         Cloth        5.000        5.000
# 14324      White   Metallic         Cloth        5.000        5.000
# 14322      White   Metallic         Cloth        5.000        5.000
# 14321      White   Metallic         Cloth        5.000        5.000
# 14320      White   Metallic         Cloth        5.000        5.000
# 14319      White   Metallic         Cloth        5.000        5.000
# 12499        Red   Metallic  Part leather        5.000        5.000
# 12501      White   Metallic  Part leather        5.000        5.000
# 12554     Silver   Metallic  Part leather        5.000        5.000
# 12604       Grey   Metallic         Cloth        5.000        5.000
# 14314      White   Metallic         Cloth        5.000        5.000
# 12768     Silver   Metallic  Full leather        5.000        5.000
# 12769      Black   Metallic  Full leather        5.000        5.000
# 12781      White   Metallic  Full leather        5.000        5.000
# 12783      White   Metallic  Full leather        5.000        5.000
# 12786     Silver   Metallic  Part leather        5.000        5.000
# 12790      White   Metallic  Part leather        5.000        5.000
# 12467       Grey   Metallic  Part leather        5.000        5.000
# 12796      Black   Metallic  Full leather        5.000        5.000
# 12800      Black   Metallic  Part leather        5.000        5.000
# 12815     Silver   Metallic  Full leather        5.000        5.000
# 12823       Grey   Metallic         Cloth        5.000        5.000
# 12835      Black   Metallic  Full leather        5.000        5.000
# 12848       Grey   Metallic  Part leather        5.000        5.000
# 12849       Grey   Metallic  Full leather        5.000        5.000
# 12798        Red   Metallic  Part leather        5.000        5.000
# 12750      Black   Metallic  Full leather        5.000        5.000
# 12670       Grey   Metallic         Cloth        5.000        5.000
# 14284      White   Metallic         Cloth        5.000        5.000
# 10559     Silver   Metallic  Full leather        5.000        5.000
# 14198     Silver   Metallic         Cloth        5.000        5.000
# 13912      Black   Metallic         Cloth        5.000        5.000
# 10194      White   Metallic         Cloth        3.000        5.000
# 7811        Grey   Metallic         Cloth        5.000        5.000
# 7810      Silver   Metallic         Cloth        5.000        5.000
# 7809       Black   Metallic         Cloth        5.000        5.000
# 7812        Blue   Metallic         Cloth        5.000        5.000
# 8128       White   Metallic         Cloth        5.000        5.000
# 15574      White   Metallic  Full leather        5.000        7.000
# 15576      White   Metallic  Full leather        5.000        7.000
# 15577      White   Metallic  Full leather        5.000        7.000
# 15578      White   Metallic  Full leather        5.000        7.000
# 15579      White   Metallic  Full leather        5.000        7.000
# 15575      White   Metallic  Full leather        5.000        7.000
# 13653       Blue  Uni/basic         Cloth        5.000        5.000
# 14668      White   Metallic         Cloth        5.000        5.000
# 14667      White   Metallic         Cloth        5.000        5.000
# 14666      White   Metallic         Cloth        5.000        5.000
# 14665      White   Metallic         Cloth        5.000        5.000
# 14620      Black   Metallic         Cloth        5.000        5.000
# 14663      White   Metallic         Cloth        4.000        5.000
# 14619      White   Metallic         Cloth        4.000        5.000
# 14661      White   Metallic         Cloth        5.000        5.000
#
#       gearing_type  engine_displacement_cc  cylinders  weight_kg drive_chain  \
# 14315       Manual                   1.000      4.000   1162.000       front
# 12473    Automatic                   1.000      4.000   1623.000       front
# 12484    Automatic                   1.000      4.000   1503.000       front
# 14328       Manual                   1.000      4.000   1162.000       front
# 14327       Manual                   1.000      4.000   1162.000       front
# 14326       Manual                   1.000      4.000   1162.000       front
# 13904       Manual                   1.000      4.000   1162.000       front
# 14325       Manual                   1.000      4.000   1162.000       front
# 14324       Manual                   1.000      4.000   1162.000       front
# 14322       Manual                   1.000      4.000   1162.000       front
# 14321       Manual                   1.000      4.000   1162.000       front
# 14320       Manual                   1.000      4.000   1162.000       front
# 14319       Manual                   1.000      4.000   1162.000       front
# 12499    Automatic                   1.000      4.000   1623.000       front
# 12501    Automatic                   1.000      4.000   1623.000       front
# 12554    Automatic                   1.000      4.000   1623.000       front
# 12604    Automatic                   1.000      4.000   1623.000       front
# 14314       Manual                   1.000      4.000   1162.000       front
# 12768       Manual                   1.000      4.000   1623.000       front
# 12769       Manual                   1.000      4.000   1487.500       front
# 12781       Manual                   1.000      4.000   1623.000       front
# 12783       Manual                   1.000      4.000   1487.500       front
# 12786       Manual                   1.000      4.000   1623.000       front
# 12790       Manual                   1.000      4.000   1623.000       front
# 12467    Automatic                   1.000      4.000   1623.000       front
# 12796       Manual                   1.000      4.000   1503.000       front
# 12800       Manual                   1.000      4.000   1623.000         4WD
# 12815       Manual                   1.000      4.000   1623.000       front
# 12823       Manual                   1.000      4.000   1623.000       front
# 12835       Manual                   1.000      4.000   1503.000       front
# 12848       Manual                   1.000      4.000   1623.000       front
# 12849       Manual                   1.000      4.000   1623.000       front
# 12798       Manual                   1.000      4.000   1623.000       front
# 12750       Manual                   1.000      4.000   1503.000       front
# 12670    Automatic                   1.000      4.000   1623.000       front
# 14284       Manual                   1.000      4.000   1162.000       front
# 10559    Automatic                   2.000      4.000   1623.000       front
# 14198       Manual                   2.000      4.000   1162.000       front
# 13912       Manual                  54.000      4.000   1162.000       front
# 10194       Manual                 122.000      4.000   1162.000       front
# 7811     Automatic                 139.000      4.000   1352.000       front
# 7810     Automatic                 139.000      4.000   1352.000       front
# 7809     Automatic                 139.000      4.000   1352.000       front
# 7812     Automatic                 139.000      4.000   1352.000       front
# 8128        Manual                 140.000      4.000   1393.000       front
# 15574    Automatic                 160.000      4.000   1685.000         4WD
# 15576    Automatic                 160.000      4.000   1685.000         4WD
# 15577    Automatic                 160.000      4.000   1685.000         4WD
# 15578    Automatic                 160.000      4.000   1685.000         4WD
# 15579    Automatic                 160.000      4.000   1685.000         4WD
# 15575    Automatic                 160.000      4.000   1685.000         4WD
# 13653       Manual                 890.000      3.000   1162.000       front
# 14668       Manual                 898.000      3.000   1091.000       front
# 14667       Manual                 898.000      3.000   1165.000       front
# 14666       Manual                 898.000      3.000   1165.000       front
# 14665       Manual                 898.000      3.000   1091.000       front
# 14620       Manual                 898.000      3.000   1092.000       front
# 14663       Manual                 898.000      3.000   1090.000       front
# 14619       Manual                 898.000      3.000   1090.000       front
# 14661       Manual                 898.000      3.000   1162.000       front
#
#           fuel  co2e_g emission_class  \
# 14315  Benzine 120.000         Euro 6
# 12473   Diesel 135.000         Euro 6
# 12484   Diesel 135.000         Euro 6
# 14328  Benzine 120.000         Euro 6
# 14327  Benzine 120.000         Euro 6
# 14326  Benzine 120.000         Euro 6
# 13904  Benzine 120.000         Euro 6
# 14325  Benzine 120.000         Euro 6
# 14324  Benzine 120.000         Euro 6
# 14322  Benzine 120.000         Euro 6
# 14321  Benzine 120.000         Euro 6
# 14320  Benzine 120.000         Euro 6
# 14319  Benzine 120.000         Euro 6
# 12499   Diesel 135.000         Euro 6
# 12501   Diesel 135.000   Euro 6d-TEMP
# 12554  Benzine 139.000         Euro 6
# 12604   Diesel 135.000         Euro 6
# 14314  Benzine 120.000         Euro 6
# 12768   Diesel 135.000         Euro 6
# 12769  Benzine 139.000         Euro 6
# 12781  Benzine 139.000         Euro 6
# 12783  Benzine 139.000         Euro 6
# 12786   Diesel 135.000         Euro 6
# 12790   Diesel 135.000         Euro 6
# 12467   Diesel 135.000         Euro 6
# 12796  Benzine 139.000         Euro 6
# 12800   Diesel 135.000         Euro 6
# 12815   Diesel 135.000         Euro 6
# 12823  Benzine 139.000         Euro 6
# 12835  Benzine 139.000         Euro 6
# 12848   Diesel 135.000         Euro 6
# 12849   Diesel 135.000         Euro 6
# 12798   Diesel 135.000         Euro 6
# 12750  Benzine 139.000         Euro 6
# 12670   Diesel 135.000         Euro 6
# 14284  Benzine 120.000         Euro 6
# 10559   Diesel 135.000         Euro 6
# 14198   Diesel  85.000         Euro 6
# 13912  Benzine 120.000         Euro 4
# 10194  Benzine 134.000   Euro 6d-TEMP
# 7811   Benzine 139.000   Euro 6d-TEMP
# 7810   Benzine 139.000   Euro 6d-TEMP
# 7809   Benzine 139.000   Euro 6d-TEMP
# 7812   Benzine 139.000   Euro 6d-TEMP
# 8128   Benzine 125.000   Euro 6d-TEMP
# 15574   Diesel 120.000         Euro 6
# 15576   Diesel 120.000         Euro 6
# 15577   Diesel 120.000         Euro 6
# 15578   Diesel 120.000         Euro 6
# 15579   Diesel 120.000         Euro 6
# 15575   Diesel 120.000         Euro 6
# 13653  LPG/CNG  98.000         Euro 6
# 14668  Benzine 113.000         Euro 6
# 14667  Benzine 113.000         Euro 6
# 14666  Benzine 113.000        Euro 6c
# 14665  Benzine 113.000         Euro 6
# 14620  Benzine 105.000         Euro 6
# 14663  Benzine 113.000         Euro 6
# 14619  Benzine 113.000        Euro 6c
# 14661  Benzine 120.000        Euro 6c
#
#                                      comfort&convenience  \
# 14315  Air conditioning,Cruise control,Electrical sid...
# 12473  Air conditioning,Automatic climate control,Cru...
# 12484  Air conditioning,Automatic climate control,Cru...
# 14328  Air conditioning,Cruise control,Electrical sid...
# 14327  Air conditioning,Cruise control,Electrical sid...
# 14326  Air conditioning,Cruise control,Electrical sid...
# 13904  Air conditioning,Cruise control,Electrical sid...
# 14325  Air conditioning,Cruise control,Electrical sid...
# 14324  Air conditioning,Cruise control,Electrical sid...
# 14322  Air conditioning,Cruise control,Electrical sid...
# 14321  Air conditioning,Cruise control,Electrical sid...
# 14320  Air conditioning,Cruise control,Electrical sid...
# 14319  Air conditioning,Cruise control,Electrical sid...
# 12499  Air conditioning,Automatic climate control,Cru...
# 12501  Air conditioning,Automatic climate control,Cru...
# 12554  Air conditioning,Automatic climate control,Cru...
# 12604  Cruise control,Electrical side mirrors,Multi-f...
# 14314  Air conditioning,Cruise control,Electrical sid...
# 12768  Air conditioning,Automatic climate control,Cru...
# 12769  Air conditioning,Automatic climate control,Cru...
# 12781  Air conditioning,Automatic climate control,Cru...
# 12783  Air conditioning,Automatic climate control,Cru...
# 12786  Air conditioning,Automatic climate control,Cru...
# 12790  Air conditioning,Automatic climate control,Cru...
# 12467  Air conditioning,Automatic climate control,Cru...
# 12796  Air conditioning,Automatic climate control,Cru...
# 12800  Air conditioning,Armrest,Automatic climate con...
# 12815  Air conditioning,Automatic climate control,Cru...
# 12823  Air conditioning,Automatic climate control,Cru...
# 12835  Air conditioning,Automatic climate control,Cru...
# 12848  Air conditioning,Automatic climate control,Aux...
# 12849  Air conditioning,Automatic climate control,Cru...
# 12798  Air conditioning,Automatic climate control,Cru...
# 12750  Air conditioning,Automatic climate control,Cru...
# 12670  Air conditioning,Armrest,Automatic climate con...
# 14284  Air conditioning,Cruise control,Electrical sid...
# 10559  Air conditioning,Automatic climate control,Cru...
# 14198  Air conditioning,Keyless central door lock,Lig...
# 13912  Electrical side mirrors,Keyless central door l...
# 10194  Air conditioning,Electrical side mirrors,Hill ...
# 7811   Air conditioning,Armrest,Automatic climate con...
# 7810   Air conditioning,Armrest,Automatic climate con...
# 7809   Air conditioning,Armrest,Automatic climate con...
# 7812   Air conditioning,Armrest,Automatic climate con...
# 8128   Air conditioning,Automatic climate control,Cru...
# 15574  Air conditioning,Automatic climate control,Cru...
# 15576  Air conditioning,Automatic climate control,Cru...
# 15577  Air conditioning,Automatic climate control,Cru...
# 15578  Air conditioning,Automatic climate control,Cru...
# 15579  Air conditioning,Automatic climate control,Cru...
# 15575  Air conditioning,Automatic climate control,Cru...
# 13653  Cruise control,Electrical side mirrors,Hill Ho...
# 14668  Air conditioning,Cruise control,Electrical sid...
# 14667  Cruise control,Electrical side mirrors,Hill Ho...
# 14666  Air conditioning,Cruise control,Electrical sid...
# 14665  Air conditioning,Cruise control,Electrical sid...
# 14620  Air conditioning,Armrest,Cruise control,Electr...
# 14663  Air conditioning,Cruise control,Electrical sid...
# 14619  Cruise control,Electrical side mirrors,Hill Ho...
# 14661                                     Cruise control
#
#                                      entertainment&media  \
# 14315                                                USB
# 12473                                          Bluetooth
# 12484                        Bluetooth,On-board computer
# 14328                                                USB
# 14327                                                USB
# 14326                                                USB
# 13904                                                USB
# 14325                                                USB
# 14324                                                USB
# 14322                                                USB
# 14321                                                USB
# 14320                                                USB
# 14319                                                USB
# 12499                        Bluetooth,On-board computer
# 12501                        Bluetooth,On-board computer
# 12554    Bluetooth,CD player,MP3,On-board computer,Radio
# 12604                        Bluetooth,On-board computer
# 14314                                                USB
# 12768   Bluetooth,Hands-free equipment,On-board computer
# 12769                        Bluetooth,On-board computer
# 12781                        Bluetooth,On-board computer
# 12783                        Bluetooth,On-board computer
# 12786                        Bluetooth,On-board computer
# 12790                        Bluetooth,On-board computer
# 12467                      Bluetooth,CD player,MP3,Radio
# 12796                        Bluetooth,On-board computer
# 12800    Bluetooth,CD player,MP3,On-board computer,Radio
# 12815                        Bluetooth,On-board computer
# 12823                        Bluetooth,On-board computer
# 12835    Bluetooth,CD player,MP3,On-board computer,Radio
# 12848                                  On-board computer
# 12849                        Bluetooth,On-board computer
# 12798                        Bluetooth,On-board computer
# 12750                        Bluetooth,On-board computer
# 12670                        Bluetooth,On-board computer
# 14284  Bluetooth,Hands-free equipment,On-board comput...
# 10559                                       Sound system
# 14198  Bluetooth,CD player,Digital radio,MP3,On-board...
# 13912              Bluetooth,MP3,On-board computer,Radio
# 10194                            On-board computer,Radio
# 7811                     MP3,On-board computer,Radio,USB
# 7810                     MP3,On-board computer,Radio,USB
# 7809                     MP3,On-board computer,Radio,USB
# 7812                         On-board computer,Radio,USB
# 8128     Bluetooth,CD player,MP3,On-board computer,Radio
# 15574                                          Radio,USB
# 15576                                          Radio,USB
# 15577                                          Radio,USB
# 15578                                          Radio,USB
# 15579                                          Radio,USB
# 15575                                          Radio,USB
# 13653          Bluetooth,MP3,On-board computer,Radio,USB
# 14668  Bluetooth,Hands-free equipment,MP3,On-board co...
# 14667  Bluetooth,Hands-free equipment,On-board comput...
# 14666  Bluetooth,Digital radio,Hands-free equipment,O...
# 14665  Bluetooth,Hands-free equipment,MP3,On-board co...
# 14620  Bluetooth,Hands-free equipment,MP3,On-board co...
# 14663  Bluetooth,Hands-free equipment,On-board comput...
# 14619                  Bluetooth,On-board computer,Radio
# 14661                  Bluetooth,On-board computer,Radio
#
#                                                   extras  \
# 14315                                       Alloy wheels
# 12473   Alloy wheels,Roof rack,Sport package,Sport seats
# 12484                                       Alloy wheels
# 14328                                       Alloy wheels
# 14327                                       Alloy wheels
# 14326                                       Alloy wheels
# 13904                                       Alloy wheels
# 14325                                       Alloy wheels
# 14324                                       Alloy wheels
# 14322                                       Alloy wheels
# 14321                                       Alloy wheels
# 14320                                       Alloy wheels
# 14319                                       Alloy wheels
# 12499                           Alloy wheels,Sport seats
# 12501                                       Alloy wheels
# 12554   Alloy wheels,Roof rack,Sport seats,Voice Control
# 12604                           Alloy wheels,Sport seats
# 14314                                       Alloy wheels
# 12768                             Alloy wheels,Roof rack
# 12769  Alloy wheels,Sport package,Sport seats,Sport s...
# 12781            Alloy wheels,Roof rack,Sport suspension
# 12783             Alloy wheels,Sport package,Sport seats
# 12786   Alloy wheels,Roof rack,Sport package,Sport seats
# 12790   Alloy wheels,Roof rack,Sport package,Sport seats
# 12467                             Alloy wheels,Roof rack
# 12796  Alloy wheels,Ski bag,Sport seats,Sport suspension
# 12800   Alloy wheels,Roof rack,Sport seats,Voice Control
# 12815   Alloy wheels,Roof rack,Sport package,Sport seats
# 12823                             Alloy wheels,Roof rack
# 12835                           Alloy wheels,Sport seats
# 12848   Alloy wheels,Roof rack,Sport package,Sport seats
# 12849   Alloy wheels,Roof rack,Sport package,Sport seats
# 12798   Alloy wheels,Roof rack,Sport package,Sport seats
# 12750             Alloy wheels,Sport package,Sport seats
# 12670                             Alloy wheels,Roof rack
# 14284  Alloy wheels,Shift paddles,Sport seats,Sport s...
# 10559  Alloy wheels,Catalytic Converter,Roof rack,Shi...
# 14198                                      Voice Control
# 13912                                       Touch screen
# 10194                                Catalytic Converter
# 7811                    Alloy wheels,Catalytic Converter
# 7810                    Alloy wheels,Catalytic Converter
# 7809                    Alloy wheels,Catalytic Converter
# 7812                    Alloy wheels,Catalytic Converter
# 8128                  Alloy wheels,Roof rack,Sport seats
# 15574                                       Alloy wheels
# 15576                                       Alloy wheels
# 15577                                       Alloy wheels
# 15578                                       Alloy wheels
# 15579                                       Alloy wheels
# 15575                                       Alloy wheels
# 13653                                       Alloy wheels
# 14668      Alloy wheels,Catalytic Converter,Touch screen
# 14667      Alloy wheels,Catalytic Converter,Touch screen
# 14666      Alloy wheels,Catalytic Converter,Touch screen
# 14665      Alloy wheels,Catalytic Converter,Touch screen
# 14620                                       Touch screen
# 14663                                       Touch screen
# 14619                                       Touch screen
# 14661                                Catalytic Converter
#
#                                          safety&security  gears  \
# 14315  ABS,Central door lock,Daytime running lights,D...  5.000
# 12473  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 12484  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 14328  ABS,Central door lock,Daytime running lights,D...  5.000
# 14327  ABS,Central door lock,Daytime running lights,D...  5.000
# 14326  ABS,Central door lock,Daytime running lights,D...  5.000
# 13904  ABS,Central door lock,Daytime running lights,D...  5.000
# 14325  ABS,Central door lock,Daytime running lights,D...  5.000
# 14324  ABS,Central door lock,Daytime running lights,D...  5.000
# 14322  ABS,Central door lock,Daytime running lights,D...  5.000
# 14321  ABS,Central door lock,Daytime running lights,D...  5.000
# 14320  ABS,Central door lock,Daytime running lights,D...  5.000
# 14319  ABS,Central door lock,Daytime running lights,D...  5.000
# 12499  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 12501  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 12554  ABS,Blind spot monitor,Central door lock,Drive...  6.000
# 12604  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 14314  ABS,Central door lock,Daytime running lights,D...  5.000
# 12768  ABS,Central door lock,Driver-side airbag,Emerg...  6.000
# 12769  ABS,Adaptive Cruise Control,Central door lock,...  6.000
# 12781  ABS,Adaptive Cruise Control,Central door lock,...  6.000
# 12783  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 12786  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 12790  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 12467  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 12796  ABS,Adaptive Cruise Control,Central door lock,...  6.000
# 12800  ABS,Central door lock,Daytime running lights,D...  6.000
# 12815  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 12823  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 12835  ABS,Adaptive Cruise Control,Central door lock,...  6.000
# 12848  ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 12849  ABS,Adaptive Cruise Control,Central door lock,...  6.000
# 12798  ABS,Adaptive Cruise Control,Central door lock,...  6.000
# 12750  ABS,Adaptive Cruise Control,Central door lock,...  6.000
# 12670  ABS,Central door lock,Daytime running lights,D...  6.000
# 14284  ABS,Central door lock,Daytime running lights,D...  5.000
# 10559  Blind spot monitor,Tire pressure monitoring sy...  6.000
# 14198  ABS,Central door lock,Daytime running lights,D...  6.000
# 13912  ABS,Power steering,Tire pressure monitoring sy...  5.000
# 10194  ABS,Central door lock,Daytime running lights,D...  5.000
# 7811   ABS,Central door lock,Daytime running lights,D...  6.000
# 7810   ABS,Central door lock,Daytime running lights,D...  6.000
# 7809   ABS,Central door lock,Daytime running lights,D...  6.000
# 7812   ABS,Central door lock,Daytime running lights,D...  6.000
# 8128   ABS,Central door lock,Driver-side airbag,Elect...  6.000
# 15574              ABS,Isofix,Power steering,Side airbag  6.000
# 15576              ABS,Isofix,Power steering,Side airbag  6.000
# 15577              ABS,Isofix,Power steering,Side airbag  6.000
# 15578              ABS,Isofix,Power steering,Side airbag  6.000
# 15579              ABS,Isofix,Power steering,Side airbag  6.000
# 15575              ABS,Isofix,Power steering,Side airbag  6.000
# 13653  ABS,Central door lock,Daytime running lights,D...  5.000
# 14668  ABS,Central door lock,Daytime running lights,D...  5.000
# 14667  ABS,Central door lock,Daytime running lights,D...  5.000
# 14666  ABS,Central door lock,Central door lock with r...  5.000
# 14665  ABS,Central door lock,Daytime running lights,D...  5.000
# 14620  ABS,Central door lock,Central door lock with r...  5.000
# 14663  ABS,Central door lock,Daytime running lights,D...  5.000
# 14619  ABS,Central door lock,Daytime running lights,D...  5.000
# 14661  ABS,Driver-side airbag,Electronic stability co...  5.000
#
#       country_version  consumption_comb  consumption_city  \
# 14315         Unknown             5.650             7.200
# 12473         Unknown             7.120             9.600
# 12484         Unknown             7.120             9.600
# 14328         Unknown             5.650             7.200
# 14327         Unknown             5.650             7.200
# 14326         Unknown             5.650             7.200
# 13904         Unknown             5.650             7.200
# 14325         Unknown             5.650             7.200
# 14324         Unknown             5.650             7.200
# 14322         Unknown             5.650             7.200
# 14321         Unknown             5.650             7.200
# 14320         Unknown             5.650             7.200
# 14319         Unknown             5.650             7.200
# 12499         Unknown             5.612             7.100
# 12501         Unknown             5.612             7.100
# 12554         Unknown             6.740             8.600
# 12604         Unknown             5.612             7.100
# 14314         Unknown             5.650             7.200
# 12768         Unknown             6.002             7.800
# 12769         Unknown             6.626             8.300
# 12781         Unknown             5.500             6.805
# 12783         Unknown             5.750             7.300
# 12786         Unknown             6.002             7.800
# 12790         Unknown             6.002             7.800
# 12467         Unknown             7.120             9.600
# 12796         Unknown             6.088             7.700
# 12800         Unknown             6.002             7.800
# 12815         Unknown             6.002             7.800
# 12823         Unknown             6.300             7.932
# 12835         Unknown             6.088             7.700
# 12848         Unknown             5.754             7.800
# 12849         Unknown             5.754             7.800
# 12798         Unknown             6.002             7.800
# 12750         Unknown             6.088             7.700
# 12670         Unknown             5.188             6.800
# 14284         Unknown             5.098             6.400
# 10559         Unknown             5.530             7.700
# 14198           Italy             3.214             3.400
# 13912         Unknown             5.650             7.200
# 10194         Germany             5.900             7.400
# 7811          Germany             6.100             7.500
# 7810          Germany             6.100             7.500
# 7809          Germany             6.100             7.500
# 7812          Germany             6.100             7.500
# 8128          Unknown             5.902             7.700
# 15574         Unknown             4.666             5.100
# 15576         Unknown             4.666             5.100
# 15577         Unknown             4.666             5.100
# 15578         Unknown             4.666             5.100
# 15579         Unknown             4.666             5.100
# 15575         Unknown             4.666             5.100
# 13653         Unknown             3.252             3.500
# 14668  European Union             4.998             6.300
# 14667         Germany             4.998             6.300
# 14666  European Union             4.998             6.300
# 14665  European Union             4.998             6.300
# 14620         Unknown             4.700             5.700
# 14663         Germany             4.998             6.300
# 14619         Germany             4.998             6.300
# 14661         Unknown             4.998             6.300
#
#        consumption_country   age
# 14315                4.700 1.000
# 12473                5.600 0.000
# 12484                5.600 0.000
# 14328                4.700 1.000
# 14327                4.700 1.000
# 14326                4.700 1.000
# 13904                4.700 2.000
# 14325                4.700 1.000
# 14324                4.700 1.000
# 14322                4.700 1.000
# 14321                4.700 1.000
# 14320                4.700 1.000
# 14319                4.700 1.000
# 12499                4.700 0.000
# 12501                4.700 0.000
# 12554                5.600 0.000
# 12604                4.700 0.000
# 14314                4.700 1.000
# 12768                4.900 0.000
# 12769                5.600 0.000
# 12781                4.700 0.000
# 12783                4.800 0.000
# 12786                4.900 0.000
# 12790                4.900 0.000
# 12467                5.600 0.000
# 12796                5.100 0.000
# 12800                4.900 0.000
# 12815                4.900 0.000
# 12823                5.300 0.000
# 12835                5.100 0.000
# 12848                4.500 0.000
# 12849                4.500 0.000
# 12798                4.900 0.000
# 12750                5.100 0.000
# 12670                4.200 0.000
# 14284                4.300 1.000
# 10559                4.200 3.000
# 14198                3.100 2.000
# 13912                4.700 2.000
# 10194                4.981 0.000
# 7811                 5.200 0.000
# 7810                 5.200 0.000
# 7809                 5.200 0.000
# 7812                 5.200 0.000
# 8128                 4.800 0.000
# 15574                4.400 0.000
# 15576                4.400 0.000
# 15577                4.400 0.000
# 15578                4.400 0.000
# 15579                4.400 0.000
# 15575                4.400 0.000
# 13653                3.100 0.000
# 14668                4.200 0.000
# 14667                4.200 0.000
# 14666                4.200 0.000
# 14665                4.200 0.000
# 14620                4.100 1.000
# 14663                4.200 0.000
# 14619                4.200 0.000
# 14661                4.200 0.000

# %%
df.loc[(df.engine_displacement_cc < 800), "engine_displacement_cc"] = np.nan

# %%
df.groupby(["make", "model","cylinders", "hp_kW"])["engine_displacement_cc"].apply(lambda x : x.fillna(x.median()) if x.median() > 0 else df["engine_displacement_cc"].median())
# Out:
# 0       1422.000
# 1       1798.000
# 2       1598.000
# 3       1422.000
# 4       1422.000
#           ...
# 15914   1997.000
# 15915   1798.000
# 15916   1997.000
# 15917   1997.000
# 15918   1798.000
# Name: engine_displacement_cc, Length: 15919, dtype: float64

# %%
df["engine_displacement_cc"] = df.groupby(["make", "model","cylinders", "hp_kW"])["engine_displacement_cc"].apply(lambda x : x.fillna(x.median()) if x.median() > 0 else df["engine_displacement_cc"].median())

# %%
detect_outlier("engine_displacement_cc")
# Out:
# column name :  engine_displacement_cc
# ----------------------------------------
# Q1 :  1229.0
# Q3 :  1598.0
# IQR :  369.0
# lower limit :  675.5
# mean        :  1427.57
# upper limit :  2151.5
# count of lower values :  0
# count of upper values :  21
#
# the smallest 10 values :
#  13653   890.000
# 14706   898.000
# 14707   898.000
# 14708   898.000
# 14494   898.000
# 14709   898.000
# 14710   898.000
# 14711   898.000
# 14712   898.000
# 14713   898.000
# Name: engine_displacement_cc, dtype: float64
#
# the biggest 10 values :
#  10771   2967.000
# 3587    2480.000
# 3596    2480.000
# 3592    2480.000
# 3593    2480.000
# 3609    2480.000
# 3608    2480.000
# 3595    2480.000
# 3598    2480.000
# 3610    2480.000
# Name: engine_displacement_cc, dtype: float64

# %%
df.loc[df.engine_displacement_cc > 2500, "engine_displacement_cc" ] = 3.0
df.loc[df.engine_displacement_cc > 2000, "engine_displacement_cc" ] = 2.5
df.loc[df.engine_displacement_cc > 1800, "engine_displacement_cc" ] = 2.0
df.loc[df.engine_displacement_cc > 1600, "engine_displacement_cc" ] = 1.8
df.loc[df.engine_displacement_cc > 1500, "engine_displacement_cc" ] = 1.6
df.loc[df.engine_displacement_cc > 1400, "engine_displacement_cc" ] = 1.5
df.loc[df.engine_displacement_cc > 1300, "engine_displacement_cc" ] = 1.4
df.loc[df.engine_displacement_cc > 1200, "engine_displacement_cc" ] = 1.3
df.loc[df.engine_displacement_cc > 1100, "engine_displacement_cc" ] = 1.2
df.loc[df.engine_displacement_cc > 800, "engine_displacement_cc" ] = 1.0

# %%
detect_outlier("engine_displacement_cc")
# Out:
# column name :  engine_displacement_cc
# ----------------------------------------
# Q1 :  1.3
# Q3 :  1.6
# IQR :  0.30000000000000004
# lower limit :  0.85
# mean        :  1.45
# upper limit :  2.0500000000000003
# count of lower values :  0
# count of upper values :  21
#
# the smallest 10 values :
#  7959   1.000
# 2391   1.000
# 2392   1.000
# 2393   1.000
# 2394   1.000
# 2395   1.000
# 2396   1.000
# 2397   1.000
# 2398   1.000
# 2399   1.000
# Name: engine_displacement_cc, dtype: float64
#
# the biggest 10 values :
#  10771   3.000
# 3601    2.500
# 3606    2.500
# 3605    2.500
# 3604    2.500
# 3608    2.500
# 3603    2.500
# 3609    2.500
# 3587    2.500
# 3649    2.500
# Name: engine_displacement_cc, dtype: float64

# %% [markdown]
# # **9.cylinders**

# %%
detect_outlier("cylinders")
# Out:
# column name :  cylinders
# ----------------------------------------
# Q1 :  4.0
# Q3 :  4.0
# IQR :  0.0
# lower limit :  4.0
# mean        :  3.79
# upper limit :  4.0
# count of lower values :  3328
# count of upper values :  32
#
# the smallest 10 values :
#  9956    1.000
# 15835   2.000
# 11342   2.000
# 0       3.000
# 2544    3.000
# 2545    3.000
# 2546    3.000
# 2547    3.000
# 2548    3.000
# 2549    3.000
# Name: cylinders, dtype: float64
#
# the biggest 10 values :
#  15151   8.000
# 15197   8.000
# 15186   8.000
# 14989   8.000
# 535     8.000
# 15165   8.000
# 15055   8.000
# 10771   6.000
# 10826   6.000
# 12897   6.000
# Name: cylinders, dtype: float64

# %%
df.loc[(df.cylinders == 1) | (df.cylinders==2), "cylinders"] = 4

# %%
detect_outlier("cylinders")
# Out:
# column name :  cylinders
# ----------------------------------------
# Q1 :  4.0
# Q3 :  4.0
# IQR :  0.0
# lower limit :  4.0
# mean        :  3.79
# upper limit :  4.0
# count of lower values :  3325
# count of upper values :  32
#
# the smallest 10 values :
#  0      3.000
# 2543   3.000
# 2544   3.000
# 2545   3.000
# 2546   3.000
# 2547   3.000
# 2548   3.000
# 2549   3.000
# 2550   3.000
# 2551   3.000
# Name: cylinders, dtype: float64
#
# the biggest 10 values :
#  535     8.000
# 15165   8.000
# 14989   8.000
# 15186   8.000
# 15055   8.000
# 15197   8.000
# 15151   8.000
# 12897   6.000
# 10826   6.000
# 10771   6.000
# Name: cylinders, dtype: float64

# %% [markdown]
# # **10.weight_kg**

# %%
detect_outlier("weight_kg")
# Out:
# column name :  weight_kg
# ----------------------------------------
# Q1 :  1180.0
# Q3 :  1472.0
# IQR :  292.0
# lower limit :  742.0
# mean        :  1345.4
# upper limit :  1910.0
# count of lower values :  3
# count of upper values :  89
#
# the smallest 10 values :
#  12779     1.000
# 8355      1.000
# 1143    102.000
# 8857    840.000
# 14313   900.000
# 13555   977.000
# 13513   977.000
# 13937   980.000
# 14105   980.000
# 13996   980.000
# Name: weight_kg, dtype: float64
#
# the biggest 10 values :
#  15678   2471.000
# 15185   2471.000
# 15231   2471.000
# 14975   2471.000
# 15280   2471.000
# 10646   2450.000
# 10638   2450.000
# 15133   2410.000
# 15136   2410.000
# 15143   2410.000
# Name: weight_kg, dtype: float64

# %%
df.loc[df.weight_kg < 103, "weight_kg"] = np.nan

# %%
df["weight_kg"] = df.groupby(["make", "model", "body_type"])["weight_kg"].apply(lambda x : x.fillna(x.mean()))

# %%
detect_outlier("weight_kg")
# Out:
# column name :  weight_kg
# ----------------------------------------
# Q1 :  1180.0
# Q3 :  1472.0
# IQR :  292.0
# lower limit :  742.0
# mean        :  1345.65
# upper limit :  1910.0
# count of lower values :  0
# count of upper values :  89
#
# the smallest 10 values :
#  8857    840.000
# 14313   900.000
# 13555   977.000
# 13513   977.000
# 14158   980.000
# 13999   980.000
# 14654   980.000
# 13935   980.000
# 13937   980.000
# 14479   980.000
# Name: weight_kg, dtype: float64
#
# the biggest 10 values :
#  15231   2471.000
# 14975   2471.000
# 15678   2471.000
# 15280   2471.000
# 15185   2471.000
# 10638   2450.000
# 10646   2450.000
# 15170   2410.000
# 15133   2410.000
# 15136   2410.000
# Name: weight_kg, dtype: float64

# %% [markdown]
# # **11.co2e_g**

# %%
detect_outlier("co2e_g")
# Out:
# column name :  co2e_g
# ----------------------------------------
# Q1 :  104.0
# Q3 :  128.0
# IQR :  24.0
# lower limit :  68.0
# mean        :  122.68
# upper limit :  164.0
# count of lower values :  7
# count of upper values :  247
#
# the smallest 10 values :
#  8110    14.000
# 3617    36.000
# 3615    36.000
# 3612    36.000
# 3356    36.000
# 12547   45.000
# 9798    51.000
# 7857    80.000
# 13668   82.000
# 8912    82.000
# Name: co2e_g, dtype: float64
#
# the biggest 10 values :
#  11888   14457.000
# 12343   13983.000
# 8542    12324.000
# 6578    12087.000
# 6579    12087.000
# 5818    12087.000
# 4089     1060.000
# 4556      990.000
# 535       331.000
# 10513     253.000
# Name: co2e_g, dtype: float64

# %%
sns.boxplot(df.co2e_g);

# %%
from scipy.stats.mstats import winsorize

# %%
Q1 = df.co2e_g.quantile(0.25)
Q3 = df.co2e_g.quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR

# %%
a = len(df.co2e_g[df.co2e_g < lower_limit])/len(df)
a
# Out:
# 0.00043972611344933726

# %%
b = len(df.co2e_g[df.co2e_g>upper_limit])/len(df)
b
# Out:
# 0.0155160500031409

# %%
winsorize(df.co2e_g, (a, b))
# Out:
# masked_array(data=[ 99., 129.,  99., ..., 139., 139., 153.],
#              mask=False,
#        fill_value=1e+20)

# %%
table_win = winsorize(df.co2e_g, (a,b))
table_win
# Out:
# masked_array(data=[ 99., 129.,  99., ..., 139., 139., 153.],
#              mask=False,
#        fill_value=1e+20)

# %%
table_win_ser = pd.Series(table_win)
table_win_ser
# Out:
# 0        99.000
# 1       129.000
# 2        99.000
# 3        99.000
# 4       109.000
#           ...
# 15914   139.000
# 15915   164.000
# 15916   139.000
# 15917   139.000
# 15918   153.000
# Length: 15919, dtype: float64

# %%
df.co2e_g = table_win_ser

# %%
sns.boxplot(df.co2e_g);

# %% [markdown]
# # **12.gears**

# %%
detect_outlier("gears")
# Out:
# column name :  gears
# ----------------------------------------
# Q1 :  5.0
# Q3 :  6.0
# IQR :  1.0
# lower limit :  3.5
# mean        :  5.94
# upper limit :  7.5
# count of lower values :  6
# count of upper values :  300
#
# the smallest 10 values :
#  14375   1.000
# 8921    1.000
# 9812    2.000
# 15817   3.000
# 15845   3.000
# 15846   3.000
# 15823   4.000
# 15822   4.000
# 10287   5.000
# 10288   5.000
# Name: gears, dtype: float64
#
# the biggest 10 values :
#  14495   50.000
# 15830    9.000
# 15827    9.000
# 15876    9.000
# 15814    9.000
# 15813    9.000
# 15812    9.000
# 15869    9.000
# 15824    9.000
# 15829    9.000
# Name: gears, dtype: float64

# %%
sns.boxplot(df.gears);

# %%
df.loc[df.gears == 50, "gears"] = 5

# %%
df.loc[df.gears <= 4, "gears"] = np.nan

# %%
df["gears"] = df.groupby(["make", "model", "body_type"])["gears"].apply(lambda x : x.fillna(x.mode()[0]))

# %%
sns.boxplot(df.gears);

# %% [markdown]
# # **13.consumption_comb**

# %%
df.drop(columns=["consumption_city", "consumption_country"], inplace=True)

# %%
detect_outlier("consumption_comb")
# Out:
# column name :  consumption_comb
# ----------------------------------------
# Q1 :  4.1
# Q3 :  5.4
# IQR :  1.3000000000000007
# lower limit :  2.1499999999999986
# mean        :  4.83
# upper limit :  7.350000000000001
# count of lower values :  4
# count of upper values :  130
#
# the smallest 10 values :
#  13678   1.200
# 3615    1.600
# 3617    1.600
# 3612    1.600
# 8872    3.100
# 8904    3.100
# 8874    3.100
# 8566    3.100
# 8912    3.100
# 13680   3.100
# Name: consumption_comb, dtype: float64
#
# the biggest 10 values :
#  535     13.800
# 10513    9.714
# 10771    9.100
# 12529    8.700
# 10817    8.700
# 10819    8.700
# 12054    8.700
# 12530    8.600
# 10789    8.600
# 12422    8.600
# Name: consumption_comb, dtype: float64

# %%
df.iloc[[13678, 3615, 3617, 3612, 535, 10513, 10771]]
# Out:
#            body_type   price_€               vat         km   hp_kW  type  \
# 13678       Off-Road  7700.000    VAT deductible  95000.000  55.000  Used
# 3615          Sedans 35899.000    VAT deductible  20880.000 110.000  Used
# 3617          Sedans 38000.000  Price negotiable  12000.000 110.000  Used
# 3612          Sedans 38450.000  Price negotiable  13800.000 110.000  Used
# 535          Compact 12990.000    VAT deductible  41200.000  70.000  Used
# 10513  Station wagon 17990.000    VAT deductible 145000.000 239.000  Used
# 10771  Station wagon 12000.000  Price negotiable 185000.000 100.000  Used
#
#        previous_owners  warranty     make     model body_color paint_type  \
# 13678            1.000     1.000  Renault      Clio      White   Metallic
# 3615             1.000     0.000     Audi        A3      White   Metallic
# 3617             1.000     0.000     Audi        A3       Grey   Metallic
# 3612             1.000     0.000     Audi        A3      Black   Metallic
# 535              1.000     0.000     Audi        A1     Silver   Metallic
# 10513            1.000     0.000     Opel  Insignia        Red   Metallic
# 10771            1.000     0.000     Opel  Insignia      White   Metallic
#
#          upholstery  nr_of_doors  nr_of_seats    gearing_type  \
# 13678         Cloth        5.000        5.000          Manual
# 3615   Part leather        5.000        5.000  Semi-automatic
# 3617   Part leather        5.000        5.000  Semi-automatic
# 3612          Cloth        5.000        5.000  Semi-automatic
# 535           Cloth        5.000        5.000          Manual
# 10513  Full leather        4.000        5.000       Automatic
# 10771         Cloth        5.000        5.000       Automatic
#
#        engine_displacement_cc  cylinders  weight_kg drive_chain      fuel  \
# 13678                   1.500      4.000   1162.000       front    Diesel
# 3615                    1.400      4.000   1615.000       front  Electric
# 3617                    1.400      4.000   1615.000       front  Electric
# 3612                    1.400      4.000   1615.000       front  Electric
# 535                     1.000      8.000   1180.000       front   Benzine
# 10513                   1.600      4.000   1623.000         4WD   Benzine
# 10771                   3.000      6.000   2295.000       front    Diesel
#
#        co2e_g emission_class  \
# 13678  85.000         Euro 6
# 3615   80.000         Euro 6
# 3617   80.000         Euro 6
# 3612   80.000         Euro 6
# 535   164.000         Euro 4
# 10513 164.000         Euro 6
# 10771 164.000         Euro 4
#
#                                      comfort&convenience  \
# 13678  Air conditioning,Cruise control,Electrical sid...
# 3615   Air conditioning,Power windows,Seat ventilatio...
# 3617   Air conditioning,Armrest,Automatic climate con...
# 3612   Air conditioning,Armrest,Automatic climate con...
# 535    Air conditioning,Automatic climate control,Ele...
# 10513  Air conditioning,Armrest,Automatic climate con...
# 10771  Air conditioning,Armrest,Automatic climate con...
#
#                                      entertainment&media  \
# 13678  Bluetooth,CD player,Digital radio,Hands-free e...
# 3615                                     Bluetooth,Radio
# 3617   Bluetooth,CD player,Digital radio,Hands-free e...
# 3612   Bluetooth,CD player,Digital radio,Hands-free e...
# 535    Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10513  Bluetooth,CD player,Digital radio,Hands-free e...
# 10771  Bluetooth,CD player,Digital radio,Hands-free e...
#
#                                                   extras  \
# 13678  Catalytic Converter,Sport package,Sport seats,...
# 3615                                        Alloy wheels
# 3617   Alloy wheels,Shift paddles,Sport package,Sport...
# 3612   Alloy wheels,Sport package,Sport seats,Voice C...
# 535                             Ski bag,Sport suspension
# 10513  Alloy wheels,Roof rack,Shift paddles,Sport pac...
# 10771  Alloy wheels,Catalytic Converter,Roof rack,Ski...
#
#                                          safety&security  gears  \
# 13678  ABS,Adaptive Cruise Control,Alarm system,Centr...  5.000
# 3615   ABS,Adaptive Cruise Control,Alarm system,Centr...  6.000
# 3617   ABS,Adaptive Cruise Control,Adaptive headlight...  6.000
# 3612   ABS,Adaptive Cruise Control,Alarm system,Centr...  6.000
# 535    ABS,Alarm system,Central door lock,Driver-side...  5.000
# 10513  ABS,Adaptive Cruise Control,Blind spot monitor...  6.000
# 10771  ABS,Adaptive Cruise Control,Adaptive headlight...  6.000
#
#       country_version  consumption_comb   age
# 13678           Italy             1.200 3.000
# 3615          Unknown             1.600 1.000
# 3617          Unknown             1.600 1.000
# 3612          Unknown             1.600 1.000
# 535           Unknown            13.800 3.000
# 10513         Germany             9.714 3.000
# 10771         Unknown             9.100 3.000

# %%
sns.boxplot(df.consumption_comb);

# %%
df.groupby(["make", "model", "body_type"])["consumption_comb"].median()
# Out:
# make     model     body_type
# Audi     A1        Compact         4.400
#                    Coupe           3.802
#                    Other           4.800
#                    Sedans          4.200
#                    Station wagon   4.200
#                    Van             5.074
#          A2        Off-Road        4.900
#          A3        Compact         4.100
#                    Convertible     4.800
#                    Coupe           3.900
#                    Other           4.150
#                    Sedans          4.032
#                    Station wagon   4.500
# Opel     Astra     Compact         4.300
#                    Coupe           6.200
#                    Off-Road        5.600
#                    Other           4.294
#                    Sedans          4.800
#                    Station wagon   4.500
#          Corsa     Compact         5.600
#                    Coupe           5.300
#                    Off-Road        5.200
#                    Other           5.200
#                    Sedans          5.300
#                    Transporter     5.300
#                    Van             5.226
#          Insignia  Compact         5.700
#                    Coupe           5.688
#                    Off-Road        6.400
#                    Other           4.300
#                    Sedans          5.360
#                    Station wagon   5.600
#                    Van             5.350
# Renault  Clio      Compact         5.200
#                    Coupe           5.900
#                    Off-Road        3.350
#                    Other           5.300
#                    Sedans          4.998
#                    Station wagon   4.998
#                    Transporter     4.998
#                    Van             5.386
#          Duster    Off-Road        4.600
#          Espace    Compact         4.683
#                    Coupe           6.015
#                    Off-Road        4.700
#                    Other           4.700
#                    Sedans          4.666
#                    Station wagon   4.700
#                    Transporter     4.700
#                    Van             4.700
# Name: consumption_comb, dtype: float64

# %%
df.consumption_comb.iloc[[13678]] = 3.35

# %%
df.consumption_comb.iloc[[535]] = 4.400

# %%
sns.boxplot(df.consumption_comb);

# %% [markdown]
# # **14.age**

# %%
detect_outlier("age")
# Out:
# column name :  age
# ----------------------------------------
# Q1 :  0.0
# Q3 :  2.0
# IQR :  2.0
# lower limit :  -3.0
# mean        :  1.39
# upper limit :  5.0
# count of lower values :  0
# count of upper values :  0
#
# the smallest 10 values :
#  7959   0.000
# 7936   0.000
# 7935   0.000
# 7934   0.000
# 7933   0.000
# 7932   0.000
# 7931   0.000
# 7930   0.000
# 7929   0.000
# 7928   0.000
# Name: age, dtype: float64
#
# the biggest 10 values :
#  0      3.000
# 5938   3.000
# 5955   3.000
# 5954   3.000
# 5953   3.000
# 5952   3.000
# 5950   3.000
# 5949   3.000
# 5947   3.000
# 5940   3.000
# Name: age, dtype: float64

# %%
import re 

def get_diff_category_column(Series:pd.Series, exclude=''',/\n''', pattern=r'''[,\n]| /''', strip='''' "!?|.,*+-_/][''', diff_value=list()):  
    diff_value.clear()
    column = Series.dropna().apply(str).str.strip(strip)
    for row in column:
        if not any(x in exclude for x in row) and row not in diff_value:
            diff_value.append(row)
        else:
            for data in map(lambda x: x.strip(strip), filter(None, re.split(pattern, row))):
                if data not in diff_value:
                    diff_value.append(data)
    return dict(enumerate(sorted(diff_value)))

# %%
col_o = ['body_type','vat','type', 'previous_owners',
       'warranty', 'make', 'model', 'body_color', 'paint_type', 'upholstery',
       'gearing_type',
       'drive_chain', 'fuel', 
       'emission_class', 'comfort&convenience', 'entertainment&media',
       'extras', 'safety&security', 'country_version']

# %%
def control_outlier(col) :
    print("column name : ",col)
    print("--"*20)
    print(get_diff_category_column(df[col]))
    print("**"*40)
    
    print("\n\n")

# %%
for col in col_o:
    control_outlier(col)
# Out:
# column name :  body_type
# ----------------------------------------
# {0: 'Compact', 1: 'Convertible', 2: 'Coupe', 3: 'Off-Road', 4: 'Other', 5: 'Sedans', 6: 'Station wagon', 7: 'Transporter', 8: 'Van'}
# ********************************************************************************
#
#
#
# column name :  vat
# ----------------------------------------
# {0: 'Price negotiable', 1: 'VAT deductible'}
# ********************************************************************************
#
#
#
# column name :  type
# ----------------------------------------
# {0: 'Demonstration', 1: "Employee's car", 2: 'New', 3: 'Pre-registered', 4: 'Used'}
# ********************************************************************************
#
#
#
# column name :  previous_owners
# ----------------------------------------
# {0: '0.0', 1: '1.0', 2: '2.0', 3: '3.0', 4: '4.0'}
# ********************************************************************************
#
#
#
# column name :  warranty
# ----------------------------------------
# {0: '0.0', 1: '1.0'}
# ********************************************************************************
#
#
#
# column name :  make
# ----------------------------------------
# {0: 'Audi', 1: 'Opel', 2: 'Renault'}
# ********************************************************************************
#
#
#
# column name :  model
# ----------------------------------------
# {0: 'A1', 1: 'A2', 2: 'A3', 3: 'Astra', 4: 'Clio', 5: 'Corsa', 6: 'Duster', 7: 'Espace', 8: 'Insignia'}
# ********************************************************************************
#
#
#
# column name :  body_color
# ----------------------------------------
# {0: 'Beige', 1: 'Black', 2: 'Blue', 3: 'Bronze', 4: 'Brown', 5: 'Gold', 6: 'Green', 7: 'Grey', 8: 'Orange', 9: 'Red', 10: 'Silver', 11: 'Violet', 12: 'White', 13: 'Yellow'}
# ********************************************************************************
#
#
#
# column name :  paint_type
# ----------------------------------------
# {0: 'Metallic', 1: 'Perl effect', 2: 'Uni/basic'}
# ********************************************************************************
#
#
#
# column name :  upholstery
# ----------------------------------------
# {0: 'Cloth', 1: 'Full leather', 2: 'Other', 3: 'Part leather', 4: 'Velour', 5: 'alcantara'}
# ********************************************************************************
#
#
#
# column name :  gearing_type
# ----------------------------------------
# {0: 'Automatic', 1: 'Manual', 2: 'Semi-automatic'}
# ********************************************************************************
#
#
#
# column name :  drive_chain
# ----------------------------------------
# {0: '4WD', 1: 'front', 2: 'rear'}
# ********************************************************************************
#
#
#
# column name :  fuel
# ----------------------------------------
# {0: 'Benzine', 1: 'Diesel', 2: 'Electric', 3: 'LPG/CNG'}
# ********************************************************************************
#
#
#
# column name :  emission_class
# ----------------------------------------
# {0: 'Euro 4', 1: 'Euro 5', 2: 'Euro 6', 3: 'Euro 6c', 4: 'Euro 6d', 5: 'Euro 6d-TEMP'}
# ********************************************************************************
#
#
#
# column name :  comfort&convenience
# ----------------------------------------
# {0: 'Air conditioning', 1: 'Air suspension', 2: 'Armrest', 3: 'Automatic climate control', 4: 'Auxiliary heating', 5: 'Cruise control', 6: 'Electric Starter', 7: 'Electric tailgate', 8: 'Electrical side mirrors', 9: 'Electrically adjustable seats', 10: 'Electrically heated windshield', 11: 'Heads-up display', 12: 'Heated steering wheel', 13: 'Hill Holder', 14: 'Keyless central door lock', 15: 'Leather seats', 16: 'Leather steering wheel', 17: 'Light sensor', 18: 'Lumbar support', 19: 'Massage seats', 20: 'Multi-function steering wheel', 21: 'Navigation system', 22: 'Panorama roof', 23: 'Park Distance Control', 24: 'Parking assist system camera', 25: 'Parking assist system self-steering', 26: 'Parking assist system sensors front', 27: 'Parking assist system sensors rear', 28: 'Power windows', 29: 'Rain sensor', 30: 'Seat heating', 31: 'Seat ventilation', 32: 'Split rear seats', 33: 'Start-stop system', 34: 'Sunroof', 35: 'Tinted windows', 36: 'Wind deflector', 37: 'Windshield'}
# ********************************************************************************
#
#
#
# column name :  entertainment&media
# ----------------------------------------
# {0: 'Bluetooth', 1: 'CD player', 2: 'Digital radio', 3: 'Hands-free equipment', 4: 'MP3', 5: 'On-board computer', 6: 'Radio', 7: 'Sound system', 8: 'Television', 9: 'USB'}
# ********************************************************************************
#
#
#
# column name :  extras
# ----------------------------------------
# {0: 'Alloy wheels', 1: 'Cab or rented Car', 2: 'Catalytic Converter', 3: 'Handicapped enabled', 4: 'Right hand drive', 5: 'Roof rack', 6: 'Shift paddles', 7: 'Ski bag', 8: 'Sliding door', 9: 'Sport package', 10: 'Sport seats', 11: 'Sport suspension', 12: 'Touch screen', 13: 'Trailer hitch', 14: 'Tuned car', 15: 'Voice Control', 16: 'Winter tyres'}
# ********************************************************************************
#
#
#
# column name :  safety&security
# ----------------------------------------
# {0: 'ABS', 1: 'Adaptive Cruise Control', 2: 'Adaptive headlights', 3: 'Alarm system', 4: 'Blind spot monitor', 5: 'Central door lock', 6: 'Central door lock with remote control', 7: 'Daytime running lights', 8: 'Driver drowsiness detection', 9: 'Driver-side airbag', 10: 'Electronic stability control', 11: 'Emergency brake assistant', 12: 'Emergency system', 13: 'Fog lights', 14: 'Head airbag', 15: 'Immobilizer', 16: 'Isofix', 17: 'LED Daytime Running Lights', 18: 'LED Headlights', 19: 'Lane departure warning system', 20: 'Night view assist', 21: 'Passenger-side airbag', 22: 'Power steering', 23: 'Rear airbag', 24: 'Side airbag', 25: 'Tire pressure monitoring system', 26: 'Traction control', 27: 'Traffic sign recognition', 28: 'Xenon headlights'}
# ********************************************************************************
#
#
#
# column name :  country_version
# ----------------------------------------
# {0: 'Austria', 1: 'Belgium', 2: 'Bulgaria', 3: 'Croatia', 4: 'Czech Republic', 5: 'Denmark', 6: 'Egypt', 7: 'European Union', 8: 'France', 9: 'Germany', 10: 'Hungary', 11: 'Italy', 12: 'Japan', 13: 'Luxembourg', 14: 'Netherlands', 15: 'Poland', 16: 'Romania', 17: 'Serbia', 18: 'Slovakia', 19: 'Slovenia', 20: 'Spain', 21: 'Sweden', 22: 'Switzerland', 23: 'Unknown'}
# ********************************************************************************

# %% [markdown]
# #HEATMAP

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu");

# %%
df.to_csv("without_outliers_aoutoscout.csv", index=False)

# %%
# The end's of handling with outliers.
